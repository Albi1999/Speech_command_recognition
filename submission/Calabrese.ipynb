# %% [markdown]
# # Speech Command Recognition: A Deep Learning Approach
#
# ## Full Code Notebook
#
# **Autor**: Alberto Calabrese
#
# **Mail**: alberto.calabrese.2@studenti.unipd.it
#
# **Student ID**: 2103405

# %% [markdown]
# # Setup

# %%
# !pip install visualkeras
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.1.4-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from visualkeras) (11.2.1)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.11/dist-packages (from visualkeras) (1.26.4)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.3.19-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (655 bytes)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.1->visualkeras) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.1->visualkeras) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.18.1->visualkeras) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.18.1->visualkeras) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.18.1->visualkeras) (2024.2.0)
# Downloading visualkeras-0.1.4-py3-none-any.whl (17 kB)
# Downloading aggdraw-1.3.19-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (997 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.4/997.4 kB 13.4 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.19 visualkeras-0.1.4

# %%
import os
import gc
import librosa
import numpy as np
import librosa.display
import random
import matplotlib.pyplot as plt
from tqdm import tqdm
import re
import hashlib
import tensorflow as tf
from collections import defaultdict, Counter
from keras import layers, models
import pickle
import json
from sklearn.utils.class_weight import compute_class_weight
import pandas as pd
from tensorflow.keras.models import load_model
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
import seaborn as sns
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras import regularizers
import time
from sklearn.preprocessing import label_binarize, MinMaxScaler
from keras.saving import register_keras_serializable
from sklearn.manifold import TSNE
from PIL import ImageFont
import visualkeras
from IPython.display import display, Image
# Out:
# 2025-08-28 14:58:28.640317: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756393108.839937      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756393108.897939      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
device_name = tf.test.gpu_device_name()
if device_name:
    print(f"GPU detected: {device_name}")
else:
    print("GPU not found. Go to Runtime > Change runtime type > GPU")
# Out:
# GPU detected: /device:GPU:0
# I0000 00:00:1756393126.078397      19 gpu_device.cc:2022] Created device /device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
SEEDS = [42, 1999, 2025]

def set_seeds(seed_value):
    tf.random.set_seed(seed_value)
    np.random.seed(seed_value)
    random.seed(seed_value)
    os.environ['PYTHONHASHSEED'] = str(seed_value)

# %%
''' 
Change this controller based on the dataset that is loaded in kaggle 
    If is loaded the dataset preprocessed locally (>1GB) set it to False
    If is loaded the original dataset (>2GB) set it to True to preprocess the data in the notebook
'''
FULL_DATASET = True

# %%
if FULL_DATASET:
    BASE_PATH = "/kaggle/input/speech-commands-v0-02/speech_commands_v0.02"
    PROCESSED_DATA_DIR = "/kaggle/working/processed_dataset"
else:
    BASE_PATH = "/kaggle/input/speechcommanddataset"
    PROCESSED_DATA_DIR = "/kaggle/input/speechcommanddataset/processed_dataset"
    
OUTPUT_DATA_DIR = "/kaggle/working"

# %% [markdown]
# # Data Preprocessing

# %%
MAX_NUM_WAVS_PER_CLASS = 2**27 - 1

def which_set(filename, validation_percentage, testing_percentage):
    """
    Determines which dataset partition a file should belong to.
    This function follows the indications of the dataset creators.
    Args:
    filename: File path of the data sample.
    validation_percentage: How much of the data set to use for validation.
    testing_percentage: How much of the data set to use for testing.

    Returns:
    String, one of 'training', 'validation', or 'testing'.
    """
    base_name = os.path.basename(filename)
    hash_name = re.sub(r'_nohash_.*$', '', base_name)
    hash_name_hashed = hashlib.sha1(hash_name.encode()).hexdigest()
    percentage_hash = ((int(hash_name_hashed, 16) %
                        (MAX_NUM_WAVS_PER_CLASS + 1)) *
                        (100.0 / MAX_NUM_WAVS_PER_CLASS))
    if percentage_hash < validation_percentage:
        result = 'val'
    elif percentage_hash < (testing_percentage + validation_percentage):
        result = 'test'
    else:
        result = 'train'
    return result

# %%
class SpeechPreprocessor:
    def __init__(self, dataset_path, output_path= PROCESSED_DATA_DIR,
                 sample_rate=16000, n_mels=40, frame_size=0.025, frame_step=0.010,
                 noise_prob=0.3):
        """
        Initializes the SpeechPreprocessor class.

        Args:
            dataset_path (str): Path to the dataset folder.
            output_path (str): Path to the output folder.
            sample_rate (int): Sampling rate of the audio files.
            n_mels (int): Number of Mel bands to generate.
            frame_size (float): Size of the frame window in seconds.
            frame_step (float): Size of the frame step in seconds.
        """
        self.dataset_path = dataset_path
        self.output_path = output_path
        self.sample_rate = sample_rate
        self.n_mels = n_mels
        self.frame_size = frame_size
        self.frame_step = frame_step
        self.noise_prob = noise_prob
        self.noise_samples = self._load_noise_samples()

        # Ensure output directories exist
        os.makedirs(self.output_path, exist_ok=True)
        for split in ["train", "val", "test"]:
            os.makedirs(f"{self.output_path}/{split}", exist_ok=True)
        print(f"Initialized SpeechPreprocessor with dataset path: {self.dataset_path} and output path: {self.output_path}")

    def _load_noise_samples(self):
        """
        Loads background noise samples from the dataset.
        Returns:
            list: List of noise samples.
        """
        noise_dir = os.path.join(self.dataset_path, "_background_noise_")
        noises = []
        for fname in os.listdir(noise_dir):
            if fname.endswith(".wav"):
                noise_path = os.path.join(noise_dir, fname)
                y, _ = librosa.load(noise_path, sr=self.sample_rate)
                noises.append(y)
        return noises

    def _time_shift(self, audio, shift_max=0.1):
        """
        Applies a random time shift to the audio signal.
        Args:
            audio (np.ndarray): Audio signal to be shifted.
            shift_max (float): Maximum shift in seconds.
        Returns:
            np.ndarray: Time-shifted audio signal.
        """
        shift = int(random.uniform(-shift_max, shift_max) * self.sample_rate)
        if shift > 0:
            audio = np.pad(audio, (shift, 0), mode='constant')[:len(audio)]
        elif shift < 0:
            audio = np.pad(audio, (0, -shift), mode='constant')[-shift:]
        return audio

    def _spec_augment(self, spectrogram, freq_mask_param=3, time_mask_param=8):
        """
        Applies SpecAugment to the spectrogram.
        Args:
            spectrogram (np.ndarray): Input spectrogram.
            freq_mask_param (int): Maximum frequency mask size.
            time_mask_param (int): Maximum time mask size.
        Returns:
            np.ndarray: Augmented spectrogram.
        """
        spec = np.copy(spectrogram)
        num_mel_channels = spec.shape[0]
        num_time_steps = spec.shape[1]

        # Frequency masking
        for _ in range(1):
            f = random.randint(0, freq_mask_param)
            f0 = random.randint(0, num_mel_channels - f)
            spec[f0:f0 + f, :] = 0

        # Time masking
        for _ in range(1):
            t = random.randint(0, time_mask_param)
            t0 = random.randint(0, num_time_steps - t)
            spec[:, t0:t0 + t] = 0

        return spec

    def _add_noise(self, audio):
        """
        Adds random background noise to the audio signal.
        Args:
            audio (np.ndarray): Audio signal to which noise will be added.
        Returns:
            np.ndarray: Audio signal with added noise.
        """
        # If no noise samples are loaded or noise probability is not met, return original audio
        if not self.noise_samples or random.random() > self.noise_prob:
            return audio

        noise = random.choice(self.noise_samples)
        if len(noise) > len(audio):
            start_idx = random.randint(0, len(noise) - len(audio))
            noise = noise[start_idx:start_idx + len(audio)]
        else:
            noise = np.pad(noise, (0, len(audio) - len(noise)))

        # Random noise level between 0.1x and 0.4x of audio signal
        noise_level = random.uniform(0.1, 0.4)
        return audio + noise_level * noise

    def _get_spectrogram(self, filepath, add_noise=False, apply_time_shift=False, apply_spec_augment=False,
                        time_shift_prob=0.5, spec_augment_prob=0.5):
        """
        Converts a .wav file into a log Mel spectrogram.

        Args:
            filepath (str): Path to the .wav file.
            add_noise (bool): Whether to add background noise to the audio.

        Returns:
            np.ndarray: Log Mel spectrogram of the audio file.
        """
        y, sr = librosa.load(filepath, sr=self.sample_rate)

        if apply_time_shift and random.random() < time_shift_prob:
            y = self._time_shift(y)

        if add_noise:
            y = self._add_noise(y)

        spectrogram = librosa.feature.melspectrogram(
            y=y, sr=sr, n_mels=self.n_mels,
            hop_length=int(self.frame_step * sr),
            n_fft=int(self.frame_size * sr)
        )
        spectrogram = librosa.power_to_db(spectrogram, ref=np.max)

        if apply_spec_augment and random.random() < spec_augment_prob:
            spectrogram = self._spec_augment(spectrogram)

        # Pad or truncate to fixed width
        target_width = 101
        if spectrogram.shape[1] < target_width:
            spectrogram = np.pad(spectrogram, ((0, 0), (0, target_width - spectrogram.shape[1])), mode="constant")
        else:
            spectrogram = spectrogram[:, :target_width]

        return spectrogram


    def process_audio_files(self):
        """
        Processes all audio files and applies dataset partitioning.
        Data augmentation is applied only to the training set.
        """
        print("Processing audio files...")

        noise_count = 0
        time_shift_count = 0
        spec_augment_count = 0

        for label in tqdm(os.listdir(self.dataset_path)):
            label_path = os.path.join(self.dataset_path, label)
            # Skip if the path is not a directory or the label is _background_noise_
            if not os.path.isdir(label_path) or label == "_background_noise_":
                continue

            for filename in os.listdir(label_path):
                if not filename.endswith(".wav"):
                    continue

                filepath = os.path.join(label_path, filename)

                # Determine dataset partition
                dataset_type = which_set(filename, 10, 10)

                # Add noise only for training set
                is_train = (dataset_type == "train")

                # Check if the spectrogram is already saved
                output_dir = os.path.join(self.output_path, dataset_type, label)
                os.makedirs(output_dir, exist_ok=True)

                output_file = os.path.join(output_dir, filename.replace(".wav", ".npy"))

                if os.path.exists(output_file):
                    continue  # Skip if the file already exists

                apply_noise = is_train and (random.random() < self.noise_prob)
                apply_time_shift = is_train and (random.random() < 0.3)
                apply_spec_augment = is_train and (random.random() < 0.3)

                # Convert to spectrogram
                spectrogram = self._get_spectrogram(
                    filepath, apply_noise, is_train, is_train,
                    time_shift_prob=0.3, spec_augment_prob=0.3
                )

                # Normalize
                spectrogram = (spectrogram - np.mean(spectrogram)) / np.std(spectrogram)

                # Save spectrogram
                np.save(output_file, spectrogram)

                # Log the augmented files
                if apply_noise:
                    noise_count += 1
                if apply_time_shift:
                    time_shift_count += 1
                if apply_spec_augment:
                    spec_augment_count += 1

        print("Data processing complete!")

        # Stats summary
        total_processed = sum(
            len([f for f in files if f.endswith(".npy")])
            for split in ["train", "val", "test"]
            for root, _, files in os.walk(os.path.join(self.output_path, split))
        )

        train_total = sum(
            len([f for f in files if f.endswith(".npy")])
            for root, _, files in os.walk(os.path.join(self.output_path, "train"))
        )

        if total_processed > 0:
            print(f"\nSummary of Preprocessing:")
            print(f"- Total samples processed: {total_processed}")

        if train_total > 0:
            print(f"- Total training samples: {train_total}")
            print(f"- Training samples with noise: {noise_count} ({(noise_count / train_total) * 100:.2f}%)")
            print(f"- Training samples with time shift: {time_shift_count} ({(time_shift_count / train_total) * 100:.2f}%)")
            print(f"- Training samples with SpecAugment: {spec_augment_count} ({(spec_augment_count / train_total) * 100:.2f}%)\n")



    def visualize_random_sample(self):
        sample_class = random.choice(os.listdir(f"{self.output_path}/train"))
        sample_file = random.choice(os.listdir(f"{self.output_path}/train/{sample_class}"))

        spectrogram = np.load(f"{self.output_path}/train/{sample_class}/{sample_file}")

        plt.figure(figsize=(10, 4))
        librosa.display.specshow(spectrogram, sr=self.sample_rate,
                                 hop_length=int(self.frame_step * self.sample_rate),
                                 x_axis="time", y_axis="mel")
        plt.colorbar(format="%+2.0f dB")
        plt.title(f"Spectrogram of {sample_file}")
        plt.show()

# %%
def preprocess():
    # Create the preprocessor instance
    processor = SpeechPreprocessor(BASE_PATH)

    # Process all audio files
    processor.process_audio_files()

    # Visualize a sample spectrogram as a sanity check
    processor.visualize_random_sample()

if FULL_DATASET:
    preprocess()
# Out:
# Initialized SpeechPreprocessor with dataset path: /kaggle/input/speech-commands-v0-02/speech_commands_v0.02 and output path: /kaggle/working/processed_dataset
# Processing audio files...
# 100%|██████████| 40/40 [16:52<00:00, 25.32s/it]
# Data processing complete!
#
# Summary of Preprocessing:
# - Total samples processed: 105829
# - Total training samples: 84843
# - Training samples with noise: 25428 (29.97%)
# - Training samples with time shift: 25413 (29.95%)
# - Training samples with SpecAugment: 25583 (30.15%)

# %%
def get_class_weights(train_path):
    """
    Computes class weights based on the number of .wav files in each class directory.

    Args:
        train_path (str): Path to the train dataset folder.

    Returns:
        class_weights (dict): {class_index: weight}
        label_to_index (dict): {label_name: index}
        index_to_label (dict): {index: label_name}
    """
    # List class names
    class_names = sorted([
        d for d in os.listdir(train_path)
        if os.path.isdir(os.path.join(train_path, d))
    ])

    label_to_index = {label: idx for idx, label in enumerate(class_names)}
    index_to_label = {idx: label for label, idx in label_to_index.items()}

    class_counts = Counter()
    for label in class_names:
        label_dir = os.path.join(train_path, label)
        num_files = len([f for f in os.listdir(label_dir) if f.endswith(".npy")])
        class_counts[label] = num_files

    y_all = np.concatenate([[label] * class_counts[label] for label in class_names])

    weights = compute_class_weight(class_weight="balanced", classes=np.array(class_names), y=y_all)
    class_weights = {label_to_index[class_names[i]]: weights[i] for i in range(len(class_names))}

    return class_weights, label_to_index, index_to_label

train_path = PROCESSED_DATA_DIR + "/train"

class_weights, label_to_index, index_to_label = get_class_weights(train_path)

# %%
with open('label_to_index.json', 'w') as f:
    json.dump(label_to_index, f)

print(label_to_index)
# Out:
# {'backward': 0, 'bed': 1, 'bird': 2, 'cat': 3, 'dog': 4, 'down': 5, 'eight': 6, 'five': 7, 'follow': 8, 'forward': 9, 'four': 10, 'go': 11, 'happy': 12, 'house': 13, 'learn': 14, 'left': 15, 'marvin': 16, 'nine': 17, 'no': 18, 'off': 19, 'on': 20, 'one': 21, 'right': 22, 'seven': 23, 'sheila': 24, 'six': 25, 'stop': 26, 'three': 27, 'tree': 28, 'two': 29, 'up': 30, 'visual': 31, 'wow': 32, 'yes': 33, 'zero': 34}

# %% [markdown]
# # Data Loading

# %%
def load_dataset(split_path, label_to_index, input_shape=(40, 101), shuffle=True):
    data = []
    labels = []

    for label in os.listdir(split_path):
        label_path = os.path.join(split_path, label)
        if not os.path.isdir(label_path):
            continue

        for fname in os.listdir(label_path):
            if not fname.endswith(".npy"):
                continue

            file_path = os.path.join(label_path, fname)
            spectrogram = np.load(file_path).astype(np.float32)

            # Ensure shape matches
            if spectrogram.shape != input_shape:
                print(f"Skipping {file_path} due to shape mismatch: {spectrogram.shape}")
                continue

            data.append(spectrogram)
            labels.append(label_to_index[label])


    data = np.array(data)[..., np.newaxis]
    labels = np.array(labels)

    dataset = tf.data.Dataset.from_tensor_slices((data, labels))
    if shuffle:
        dataset = dataset.shuffle(buffer_size=len(data))

    return dataset, data, labels

# %%
train_ds, _, _ = load_dataset(os.path.join(PROCESSED_DATA_DIR, "train"), label_to_index)
val_ds, _, _ = load_dataset(os.path.join(PROCESSED_DATA_DIR, "val"), label_to_index, shuffle=False)
test_ds, X_test, y_test = load_dataset(os.path.join(PROCESSED_DATA_DIR, "test"), label_to_index, shuffle=False)


BATCH_SIZE = 64
train_ds = train_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
# Out:
# I0000 00:00:1756394166.519848      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %% [markdown]
# # Utils

# %%
def save_and_plot_results(history, model, model_name, saving_dir, transformer = False):
    """
    Save the model training history, its metadata and plots results for accuracy and loss.
    Also, visualize and save the model architecture using visualkeras with custom text.
    Args:
        history
        model
        model_name (str)
        saving_dir (str)
        transformer (bool)
    """
    print(f"\n--- Saving results for model: {model_name} ---")
    
    os.makedirs(saving_dir, exist_ok=True)

    history_dict = history.history

    plt.figure(figsize=(10, 6))
    plt.plot(history_dict['loss'], label='Training Loss', marker='o')
    plt.plot(history_dict['val_loss'], label='Validation Loss', marker='o')
    plt.title(f"Loss: {model_name.replace('_', ' ').title()}", fontsize=16)
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('Loss', fontsize=12)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    loss_path = os.path.join(saving_dir, f"{model_name}_loss.png")
    plt.savefig(loss_path)
    plt.show()
    print(f"Loss plot saved to {loss_path}")

    plt.figure(figsize=(10, 6))
    plt.plot(history_dict['accuracy'], label='Training Accuracy', marker='o')
    plt.plot(history_dict['val_accuracy'], label='Validation Accuracy', marker='o')
    plt.title(f"Accuracy: {model_name.replace('_', ' ').title()}", fontsize=16)
    plt.xlabel('Epoch', fontsize=12)
    plt.ylabel('Accuracy', fontsize=12)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    accuracy_path = os.path.join(saving_dir, f"{model_name}_accuracy.png")
    plt.savefig(accuracy_path)
    plt.show()
    print(f"Accuracy plot saved to {accuracy_path}")

    history_path = os.path.join(saving_dir, "training_history.pkl")
    with open(history_path, "wb") as f:
        pickle.dump(history_dict, f)
    print(f"Training history saved to {history_path}")

    if transformer == False: # Excluded Transformer based models and Hybrid CNN BiLSTM from architecture plotting (problems with visualkeras)
        print(f"\n--- Plotting model architecture for: {model_name} ---")
        architecture_path = os.path.join(saving_dir, f"{model_name}_architecture.png")
        architecture_path_custom = os.path.join(saving_dir, f"{model_name}_architecture_custom.png")
            
        visualkeras.layered_view(model, legend=True, to_file=architecture_path)
        visualkeras.layered_view(model, legend=True, to_file=architecture_path_custom, show_dimension=True)
        print("Model architecture plot saved")
        display(Image(filename=architecture_path_custom))

# %%
def get_callbacks(checkpoint_path):
    return [
        EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1),
        ModelCheckpoint(filepath=checkpoint_path, monitor='val_accuracy', save_best_only=True, mode='max'),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)
    ]

# %%
def train_models(model_name, model_instance, seed):
    saving_dir = f"{OUTPUT_DATA_DIR}/{model_name}"
    os.makedirs(saving_dir, exist_ok=True)
    checkpoint_path = os.path.join(saving_dir, f"{model_name}_seed_{seed}_best.keras")
    metadata_path = os.path.join(saving_dir, f"metadata_{model_name}_seed_{seed}.json")

    model_instance.compile()
    model = model_instance.get_model()

    history = model.fit(
        train_ds, validation_data=val_ds, epochs=20,
        class_weight=class_weights,
        callbacks=get_callbacks(checkpoint_path)
    )

    best_epoch_idx = np.argmax(history.history['val_accuracy'])
    metadata = {
        "model_name": model_name,
        "seed": seed,
        "epochs_trained": int(best_epoch_idx + 1),
        "best_train_acc": round(float(history.history['accuracy'][best_epoch_idx]), 4),
        "best_val_acc": round(float(history.history['val_accuracy'][best_epoch_idx]), 4),
        "input_shape": list(model.input_shape),
        "output_shape": list(model.output_shape),
        "num_params": int(model.count_params())
    }
    with open(metadata_path, "w") as f:
        json.dump(metadata, f, indent=4)
    print(f"Metadata for seed {seed} saved to {metadata_path}")

    tf.keras.backend.clear_session()
    gc.collect()

    return history, checkpoint_path, saving_dir

# %% [markdown]
# # Models Definition and Training

# %% [markdown]
# ## Baseline CNN

# %%
def baseline_cnn(input_shape=(40, 101, 1), num_classes = len(label_to_index)):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        layers.Conv2D(32, (3,3), activation='relu'),
        layers.BatchNormalization(),
        layers.Conv2D(64, (3,3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2,2)),
        layers.Dropout(0.25),
        layers.GlobalAveragePooling2D(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax')
    ])
    lr = 1e-3
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
    loss = 'sparse_categorical_crossentropy'
    metrics = ['accuracy']
    model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
    return model

# %%
model_name = "baseline_cnn"
print(f"\nTRAINING MODEL: {model_name.upper()}")

best_seed_history = None
best_seed_val_accuracy = 0.0
best_seed_checkpoint_path = ""

for seed in SEEDS:
    set_seeds(seed)
    print(f"\n--- Training '{model_name}' with Seed: {seed} ---")

    model = baseline_cnn(input_shape=(40, 101, 1), num_classes=len(label_to_index))
    
    saving_dir_baseline = f"{OUTPUT_DATA_DIR}/{model_name}"
    os.makedirs(saving_dir_baseline, exist_ok=True)
    checkpoint_path = os.path.join(saving_dir_baseline, f"{model_name}_seed_{seed}_best.keras")
    metadata_path = os.path.join(saving_dir_baseline, f"metadata_{model_name}_seed_{seed}.json")

    history = model.fit(
        train_ds, validation_data=val_ds, epochs=20,
        class_weight=class_weights,
        callbacks=get_callbacks(checkpoint_path)
    )

    history_dict = history.history
    best_epoch_idx = np.argmax(history_dict['val_accuracy'])
    best_train_acc = history_dict['accuracy'][best_epoch_idx]
    best_val_acc = history_dict['val_accuracy'][best_epoch_idx]
    effective_epochs = best_epoch_idx + 1
    
    metadata = {
        "model_name": model_name,
        "seed": seed,
        "epochs_trained": int(effective_epochs),
        "best_train_acc": round(float(best_train_acc), 4),
        "best_val_acc": round(float(best_val_acc), 4),
        "input_shape": list(model.input_shape),
        "output_shape": list(model.output_shape),
        "num_params": int(model.count_params())
    }
    
    with open(metadata_path, "w") as f:
        json.dump(metadata, f, indent=4)
    print(f"Metadata for seed {seed} saved to {metadata_path}")
    
    current_best_val_acc = max(history.history['val_accuracy'])
    if current_best_val_acc > best_seed_val_accuracy:
        best_seed_val_accuracy = current_best_val_acc
        best_seed_history = history
        best_seed_checkpoint_path = checkpoint_path
        
    tf.keras.backend.clear_session()
    gc.collect()
# Out:
# TRAINING MODEL: BASELINE_CNN
#
# --- Training 'baseline_cnn' with Seed: 42 ---
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1756394180.634171      74 service.cc:148] XLA service 0x7d4c6800df80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1756394180.634943      74 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1756394181.042360      74 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   16/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.0331 - loss: 3.5426
# I0000 00:00:1756394185.260039      74 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 15ms/step - accuracy: 0.0766 - loss: 3.3906 - val_accuracy: 0.2049 - val_loss: 2.7798 - learning_rate: 0.0010
# Epoch 2/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.2934 - loss: 2.4508 - val_accuracy: 0.4552 - val_loss: 1.9097 - learning_rate: 0.0010
# Epoch 3/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.4354 - loss: 1.9465 - val_accuracy: 0.5338 - val_loss: 1.5492 - learning_rate: 0.0010
# Epoch 4/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.4874 - loss: 1.7574 - val_accuracy: 0.5688 - val_loss: 1.4643 - learning_rate: 0.0010
# Epoch 5/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.5276 - loss: 1.6176 - val_accuracy: 0.5284 - val_loss: 1.6050 - learning_rate: 0.0010
# Epoch 6/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.5527 - loss: 1.5390 - val_accuracy: 0.5898 - val_loss: 1.3615 - learning_rate: 0.0010
# Epoch 7/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.5645 - loss: 1.4929 - val_accuracy: 0.6941 - val_loss: 1.0351 - learning_rate: 0.0010
# Epoch 8/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.5771 - loss: 1.4525 - val_accuracy: 0.6628 - val_loss: 1.1287 - learning_rate: 0.0010
# Epoch 9/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.5818 - loss: 1.4306 - val_accuracy: 0.6609 - val_loss: 1.1566 - learning_rate: 0.0010
# Epoch 10/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5907 - loss: 1.3945
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.5907 - loss: 1.3945 - val_accuracy: 0.6640 - val_loss: 1.1270 - learning_rate: 0.0010
# Epoch 11/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.6107 - loss: 1.3336 - val_accuracy: 0.7094 - val_loss: 0.9708 - learning_rate: 5.0000e-04
# Epoch 12/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.6178 - loss: 1.3107 - val_accuracy: 0.7179 - val_loss: 0.9426 - learning_rate: 5.0000e-04
# Epoch 13/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.6162 - loss: 1.3087 - val_accuracy: 0.7262 - val_loss: 0.9244 - learning_rate: 5.0000e-04
# Epoch 14/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6226 - loss: 1.2911 - val_accuracy: 0.7233 - val_loss: 0.9267 - learning_rate: 5.0000e-04
# Epoch 15/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.6284 - loss: 1.2838 - val_accuracy: 0.6895 - val_loss: 1.0447 - learning_rate: 5.0000e-04
# Epoch 16/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.6288 - loss: 1.2685 - val_accuracy: 0.7323 - val_loss: 0.9020 - learning_rate: 5.0000e-04
# Epoch 17/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.6293 - loss: 1.2677 - val_accuracy: 0.7312 - val_loss: 0.9153 - learning_rate: 5.0000e-04
# Epoch 18/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6290 - loss: 1.2611 - val_accuracy: 0.7437 - val_loss: 0.8735 - learning_rate: 5.0000e-04
# Epoch 19/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6335 - loss: 1.2525 - val_accuracy: 0.7408 - val_loss: 0.8883 - learning_rate: 5.0000e-04
# Epoch 20/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6370 - loss: 1.2356 - val_accuracy: 0.7415 - val_loss: 0.8776 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 18.
# Metadata for seed 42 saved to /kaggle/working/baseline_cnn/metadata_baseline_cnn_seed_42.json
#
# --- Training 'baseline_cnn' with Seed: 1999 ---
# Epoch 1/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 27s 14ms/step - accuracy: 0.0814 - loss: 3.3726 - val_accuracy: 0.0863 - val_loss: 3.6131 - learning_rate: 0.0010
# Epoch 2/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.3026 - loss: 2.4264 - val_accuracy: 0.3409 - val_loss: 2.2787 - learning_rate: 0.0010
# Epoch 3/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.4411 - loss: 1.9294 - val_accuracy: 0.5033 - val_loss: 1.6510 - learning_rate: 0.0010
# Epoch 4/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.4988 - loss: 1.7288 - val_accuracy: 0.5880 - val_loss: 1.4054 - learning_rate: 0.0010
# Epoch 5/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.5355 - loss: 1.6117 - val_accuracy: 0.5719 - val_loss: 1.4985 - learning_rate: 0.0010
# Epoch 6/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.5540 - loss: 1.5358 - val_accuracy: 0.6290 - val_loss: 1.2487 - learning_rate: 0.0010
# Epoch 7/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.5697 - loss: 1.4886 - val_accuracy: 0.6959 - val_loss: 1.0643 - learning_rate: 0.0010
# Epoch 8/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.5789 - loss: 1.4452 - val_accuracy: 0.5728 - val_loss: 1.4639 - learning_rate: 0.0010
# Epoch 9/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.5879 - loss: 1.4119 - val_accuracy: 0.6614 - val_loss: 1.1951 - learning_rate: 0.0010
# Epoch 10/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5939 - loss: 1.3794
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.5939 - loss: 1.3794 - val_accuracy: 0.6726 - val_loss: 1.1036 - learning_rate: 0.0010
# Epoch 11/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6140 - loss: 1.3201 - val_accuracy: 0.6924 - val_loss: 1.0381 - learning_rate: 5.0000e-04
# Epoch 12/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6234 - loss: 1.2883 - val_accuracy: 0.7451 - val_loss: 0.8532 - learning_rate: 5.0000e-04
# Epoch 13/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6244 - loss: 1.2816 - val_accuracy: 0.7213 - val_loss: 0.9307 - learning_rate: 5.0000e-04
# Epoch 14/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6253 - loss: 1.2822 - val_accuracy: 0.7441 - val_loss: 0.8522 - learning_rate: 5.0000e-04
# Epoch 15/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6292 - loss: 1.2725 - val_accuracy: 0.7266 - val_loss: 0.9169 - learning_rate: 5.0000e-04
# Epoch 16/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6286 - loss: 1.2672 - val_accuracy: 0.7549 - val_loss: 0.8321 - learning_rate: 5.0000e-04
# Epoch 17/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6357 - loss: 1.2534 - val_accuracy: 0.7029 - val_loss: 1.0050 - learning_rate: 5.0000e-04
# Epoch 18/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6318 - loss: 1.2570 - val_accuracy: 0.7044 - val_loss: 0.9619 - learning_rate: 5.0000e-04
# Epoch 19/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6378 - loss: 1.2276
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6377 - loss: 1.2276 - val_accuracy: 0.7290 - val_loss: 0.9365 - learning_rate: 5.0000e-04
# Epoch 20/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6419 - loss: 1.2051 - val_accuracy: 0.7753 - val_loss: 0.7707 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 20.
# Metadata for seed 1999 saved to /kaggle/working/baseline_cnn/metadata_baseline_cnn_seed_1999.json
#
# --- Training 'baseline_cnn' with Seed: 2025 ---
# Epoch 1/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 26s 14ms/step - accuracy: 0.0760 - loss: 3.3971 - val_accuracy: 0.1723 - val_loss: 2.9685 - learning_rate: 0.0010
# Epoch 2/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.2887 - loss: 2.4760 - val_accuracy: 0.3463 - val_loss: 2.1759 - learning_rate: 0.0010
# Epoch 3/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.4266 - loss: 1.9561 - val_accuracy: 0.4116 - val_loss: 1.9355 - learning_rate: 0.0010
# Epoch 4/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.4837 - loss: 1.7590 - val_accuracy: 0.6010 - val_loss: 1.3743 - learning_rate: 0.0010
# Epoch 5/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.5206 - loss: 1.6447 - val_accuracy: 0.5828 - val_loss: 1.4025 - learning_rate: 0.0010
# Epoch 6/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.5449 - loss: 1.5546 - val_accuracy: 0.6241 - val_loss: 1.2505 - learning_rate: 0.0010
# Epoch 7/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.5639 - loss: 1.5002 - val_accuracy: 0.5643 - val_loss: 1.4673 - learning_rate: 0.0010
# Epoch 8/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.5756 - loss: 1.4567 - val_accuracy: 0.6540 - val_loss: 1.1507 - learning_rate: 0.0010
# Epoch 9/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.5848 - loss: 1.4207 - val_accuracy: 0.6707 - val_loss: 1.1204 - learning_rate: 0.0010
# Epoch 10/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.5927 - loss: 1.3923 - val_accuracy: 0.7001 - val_loss: 1.0216 - learning_rate: 0.0010
# Epoch 11/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.5970 - loss: 1.3808 - val_accuracy: 0.5689 - val_loss: 1.4342 - learning_rate: 0.0010
# Epoch 12/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.5989 - loss: 1.3601 - val_accuracy: 0.6730 - val_loss: 1.0862 - learning_rate: 0.0010
# Epoch 13/20
# 1321/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6120 - loss: 1.3383
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6120 - loss: 1.3383 - val_accuracy: 0.6550 - val_loss: 1.1365 - learning_rate: 0.0010
# Epoch 14/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6238 - loss: 1.2751 - val_accuracy: 0.7291 - val_loss: 0.8888 - learning_rate: 5.0000e-04
# Epoch 15/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6309 - loss: 1.2587 - val_accuracy: 0.7467 - val_loss: 0.8462 - learning_rate: 5.0000e-04
# Epoch 16/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6315 - loss: 1.2523 - val_accuracy: 0.7442 - val_loss: 0.8536 - learning_rate: 5.0000e-04
# Epoch 17/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6362 - loss: 1.2500 - val_accuracy: 0.7526 - val_loss: 0.8577 - learning_rate: 5.0000e-04
# Epoch 18/20
# 1325/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6344 - loss: 1.2350
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6344 - loss: 1.2350 - val_accuracy: 0.7378 - val_loss: 0.8795 - learning_rate: 5.0000e-04
# Epoch 19/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6440 - loss: 1.2165 - val_accuracy: 0.7612 - val_loss: 0.8116 - learning_rate: 2.5000e-04
# Epoch 20/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6472 - loss: 1.2024 - val_accuracy: 0.7734 - val_loss: 0.7661 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 20.
# Metadata for seed 2025 saved to /kaggle/working/baseline_cnn/metadata_baseline_cnn_seed_2025.json

# %%
model = load_model(best_seed_checkpoint_path)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 38, 99, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 38, 99, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 36, 97, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 36, 97, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 18, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 18, 48, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 35)             │         4,515 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 95,723 (373.92 KB)
#  Trainable params: 31,843 (124.39 KB)
#  Non-trainable params: 192 (768.00 B)
#  Optimizer params: 63,688 (248.79 KB)

# %%
val_loss, val_acc = model.evaluate(val_ds)

test_loss, test_acc = model.evaluate(test_ds)

print(f"\nValidation accuracy: {val_acc:.4f}")
print(f"Validation loss: {val_loss:.4f}")

print(f"\nTest accuracy: {test_acc:.4f}")
print(f"Test loss: {test_loss:.4f}")
# Out:
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7951 - loss: 0.7134
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7889 - loss: 0.7402
#
# Validation accuracy: 0.7753
# Validation loss: 0.7707
#
# Test accuracy: 0.7661
# Test loss: 0.7981

# %%
save_and_plot_results(history, model, model_name, saving_dir_baseline)
# Out:
# --- Saving results for model: baseline_cnn ---
# Loss plot saved to /kaggle/working/baseline_cnn/baseline_cnn_loss.png
# Accuracy plot saved to /kaggle/working/baseline_cnn/baseline_cnn_accuracy.png
# Training history saved to /kaggle/working/baseline_cnn/training_history.pkl
#
# --- Plotting model architecture for: baseline_cnn ---
# Model architecture plot saved
# /usr/local/lib/python3.11/dist-packages/visualkeras/layered.py:86: UserWarning: The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.
#   warnings.warn("The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.")

# %% [markdown]
# ## Residual CNN (ResNet)

# %%
class ResidualCNN:
    def __init__(self, input_shape=(40, 101, 1), num_classes=len(label_to_index)):
        self.input_shape = input_shape
        self.num_classes = num_classes
        self.model = self._build_model()

    def _res_block(self, x, filters, stride=1):
        shortcut = x

        # First convolutional layer
        x = layers.Conv2D(filters, kernel_size=3, strides=stride, padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = layers.ReLU()(x)

        # Second convolutional layer
        x = layers.Conv2D(filters, kernel_size=3, strides=1, padding='same')(x)
        x = layers.BatchNormalization()(x)

        # Shortcut connection
        if stride != 1 or shortcut.shape[-1] != filters:
            shortcut = layers.Conv2D(filters, kernel_size=1, strides=stride, padding='same')(shortcut)
            shortcut = layers.BatchNormalization()(shortcut)

        x = layers.add([x, shortcut])
        x = layers.ReLU()(x)
        return x

    def _build_model(self):
        inputs = layers.Input(shape=self.input_shape)

        x = layers.Conv2D(32, kernel_size=3, strides=1, padding='same')(inputs)
        x = layers.BatchNormalization()(x)
        x = layers.ReLU()(x)

        # Residual blocks
        x = self._res_block(x, 32)
        x = self._res_block(x, 64, stride=2)
        x = self._res_block(x, 128, stride=2)

        x = layers.GlobalAveragePooling2D(name="feature_embedding")(x)
        x = layers.Dropout(0.3)(x)
        outputs = layers.Dense(self.num_classes, activation='softmax')(x)

        model = models.Model(inputs, outputs)
        return model

    def compile(self, optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy']):
        self.model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

    def get_model(self):
        return self.model

# %%
model_name = "residual_cnn"
print(f"\n{'='*20} TRAINING MODEL: {model_name.upper()}")

best_seed_history = None
best_seed_val_accuracy = 0.0
best_seed_checkpoint_path = ""

for seed in SEEDS:
    set_seeds(seed)
    print(f"\n--- Training '{model_name}' with Seed: {seed} ---")

    model_instance = ResidualCNN(input_shape=(40, 101, 1), num_classes=len(label_to_index))
    history, checkpoint_path, saving_dir = train_models(model_name, model_instance, seed)

    current_best_val_acc = max(history.history['val_accuracy'])
    if current_best_val_acc > best_seed_val_accuracy:
        best_seed_val_accuracy = current_best_val_acc
        best_seed_history = history
        best_seed_checkpoint_path = checkpoint_path
# Out:
# ==================== TRAINING MODEL: RESIDUAL_CNN
#
# --- Training 'residual_cnn' with Seed: 42 ---
# Epoch 1/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 58s 30ms/step - accuracy: 0.2679 - loss: 2.7164 - val_accuracy: 0.7839 - val_loss: 0.8210 - learning_rate: 0.0010
# Epoch 2/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.7655 - loss: 0.8591 - val_accuracy: 0.8722 - val_loss: 0.4566 - learning_rate: 0.0010
# Epoch 3/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.8316 - loss: 0.5978 - val_accuracy: 0.8603 - val_loss: 0.4494 - learning_rate: 0.0010
# Epoch 4/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.8601 - loss: 0.4885 - val_accuracy: 0.9050 - val_loss: 0.3336 - learning_rate: 0.0010
# Epoch 5/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.8743 - loss: 0.4291 - val_accuracy: 0.9253 - val_loss: 0.2566 - learning_rate: 0.0010
# Epoch 6/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.8887 - loss: 0.3870 - val_accuracy: 0.9288 - val_loss: 0.2475 - learning_rate: 0.0010
# Epoch 7/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.8950 - loss: 0.3618 - val_accuracy: 0.9394 - val_loss: 0.2174 - learning_rate: 0.0010
# Epoch 8/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.9045 - loss: 0.3282 - val_accuracy: 0.9262 - val_loss: 0.2486 - learning_rate: 0.0010
# Epoch 9/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.9099 - loss: 0.3046 - val_accuracy: 0.9120 - val_loss: 0.2858 - learning_rate: 0.0010
# Epoch 10/20
# 1324/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9143 - loss: 0.2945
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.9143 - loss: 0.2945 - val_accuracy: 0.9300 - val_loss: 0.2418 - learning_rate: 0.0010
# Epoch 11/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.9291 - loss: 0.2374 - val_accuracy: 0.9511 - val_loss: 0.1717 - learning_rate: 5.0000e-04
# Epoch 12/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.9366 - loss: 0.2134 - val_accuracy: 0.9498 - val_loss: 0.1716 - learning_rate: 5.0000e-04
# Epoch 13/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.9373 - loss: 0.2114 - val_accuracy: 0.9536 - val_loss: 0.1650 - learning_rate: 5.0000e-04
# Epoch 14/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.9422 - loss: 0.1925 - val_accuracy: 0.9546 - val_loss: 0.1631 - learning_rate: 5.0000e-04
# Epoch 15/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.9447 - loss: 0.1832 - val_accuracy: 0.9502 - val_loss: 0.1680 - learning_rate: 5.0000e-04
# Epoch 16/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.9460 - loss: 0.1768 - val_accuracy: 0.9521 - val_loss: 0.1639 - learning_rate: 5.0000e-04
# Epoch 17/20
# 1324/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9484 - loss: 0.1687
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.9484 - loss: 0.1687 - val_accuracy: 0.9547 - val_loss: 0.1637 - learning_rate: 5.0000e-04
# Epoch 18/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.9581 - loss: 0.1415 - val_accuracy: 0.9563 - val_loss: 0.1546 - learning_rate: 2.5000e-04
# Epoch 19/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.9595 - loss: 0.1352 - val_accuracy: 0.9572 - val_loss: 0.1532 - learning_rate: 2.5000e-04
# Epoch 20/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9620 - loss: 0.1269 - val_accuracy: 0.9544 - val_loss: 0.1605 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 19.
# Metadata for seed 42 saved to /kaggle/working/residual_cnn/metadata_residual_cnn_seed_42.json
#
# --- Training 'residual_cnn' with Seed: 1999 ---
# Epoch 1/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - accuracy: 0.2960 - loss: 2.6032 - val_accuracy: 0.6117 - val_loss: 1.3071 - learning_rate: 0.0010
# Epoch 2/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.7665 - loss: 0.8506 - val_accuracy: 0.8706 - val_loss: 0.4904 - learning_rate: 0.0010
# Epoch 3/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.8326 - loss: 0.5983 - val_accuracy: 0.8945 - val_loss: 0.3716 - learning_rate: 0.0010
# Epoch 4/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.8580 - loss: 0.4936 - val_accuracy: 0.8523 - val_loss: 0.5052 - learning_rate: 0.0010
# Epoch 5/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.8762 - loss: 0.4288 - val_accuracy: 0.8999 - val_loss: 0.3519 - learning_rate: 0.0010
# Epoch 6/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.8897 - loss: 0.3795 - val_accuracy: 0.9141 - val_loss: 0.2926 - learning_rate: 0.0010
# Epoch 7/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.8977 - loss: 0.3518 - val_accuracy: 0.9327 - val_loss: 0.2429 - learning_rate: 0.0010
# Epoch 8/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9056 - loss: 0.3270 - val_accuracy: 0.9168 - val_loss: 0.2745 - learning_rate: 0.0010
# Epoch 9/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9096 - loss: 0.3077 - val_accuracy: 0.9372 - val_loss: 0.2233 - learning_rate: 0.0010
# Epoch 10/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 24ms/step - accuracy: 0.9143 - loss: 0.2896 - val_accuracy: 0.9305 - val_loss: 0.2361 - learning_rate: 0.0010
# Epoch 11/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9199 - loss: 0.2682 - val_accuracy: 0.9441 - val_loss: 0.1983 - learning_rate: 0.0010
# Epoch 12/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9239 - loss: 0.2557 - val_accuracy: 0.9422 - val_loss: 0.2027 - learning_rate: 0.0010
# Epoch 13/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9289 - loss: 0.2424 - val_accuracy: 0.9325 - val_loss: 0.2426 - learning_rate: 0.0010
# Epoch 14/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9320 - loss: 0.2276 - val_accuracy: 0.9437 - val_loss: 0.1939 - learning_rate: 0.0010
# Epoch 15/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9363 - loss: 0.2117 - val_accuracy: 0.9403 - val_loss: 0.2063 - learning_rate: 0.0010
# Epoch 16/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9371 - loss: 0.2040 - val_accuracy: 0.9402 - val_loss: 0.2139 - learning_rate: 0.0010
# Epoch 17/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9399 - loss: 0.1960 - val_accuracy: 0.9493 - val_loss: 0.1777 - learning_rate: 0.0010
# Epoch 18/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9431 - loss: 0.1882 - val_accuracy: 0.9381 - val_loss: 0.2197 - learning_rate: 0.0010
# Epoch 19/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9436 - loss: 0.1819 - val_accuracy: 0.9498 - val_loss: 0.1783 - learning_rate: 0.0010
# Epoch 20/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 24ms/step - accuracy: 0.9474 - loss: 0.1701 - val_accuracy: 0.9517 - val_loss: 0.1734 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 20.
# Metadata for seed 1999 saved to /kaggle/working/residual_cnn/metadata_residual_cnn_seed_1999.json
#
# --- Training 'residual_cnn' with Seed: 2025 ---
# Epoch 1/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 53s 28ms/step - accuracy: 0.2776 - loss: 2.6800 - val_accuracy: 0.7396 - val_loss: 0.9279 - learning_rate: 0.0010
# Epoch 2/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.7633 - loss: 0.8698 - val_accuracy: 0.8846 - val_loss: 0.4246 - learning_rate: 0.0010
# Epoch 3/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.8321 - loss: 0.6034 - val_accuracy: 0.8707 - val_loss: 0.4329 - learning_rate: 0.0010
# Epoch 4/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.8580 - loss: 0.4920 - val_accuracy: 0.9064 - val_loss: 0.3271 - learning_rate: 0.0010
# Epoch 5/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.8785 - loss: 0.4233 - val_accuracy: 0.9191 - val_loss: 0.2769 - learning_rate: 0.0010
# Epoch 6/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.8905 - loss: 0.3830 - val_accuracy: 0.9091 - val_loss: 0.3209 - learning_rate: 0.0010
# Epoch 7/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.8982 - loss: 0.3486 - val_accuracy: 0.9176 - val_loss: 0.2800 - learning_rate: 0.0010
# Epoch 8/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.9071 - loss: 0.3162 - val_accuracy: 0.9308 - val_loss: 0.2425 - learning_rate: 0.0010
# Epoch 9/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9105 - loss: 0.3052 - val_accuracy: 0.9393 - val_loss: 0.2264 - learning_rate: 0.0010
# Epoch 10/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 32s 24ms/step - accuracy: 0.9169 - loss: 0.2796 - val_accuracy: 0.9413 - val_loss: 0.1999 - learning_rate: 0.0010
# Epoch 11/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9197 - loss: 0.2728 - val_accuracy: 0.9384 - val_loss: 0.2239 - learning_rate: 0.0010
# Epoch 12/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9255 - loss: 0.2499 - val_accuracy: 0.9398 - val_loss: 0.2123 - learning_rate: 0.0010
# Epoch 13/20
# 1325/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9280 - loss: 0.2409
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9280 - loss: 0.2409 - val_accuracy: 0.9406 - val_loss: 0.2171 - learning_rate: 0.0010
# Epoch 14/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9420 - loss: 0.1944 - val_accuracy: 0.9550 - val_loss: 0.1654 - learning_rate: 5.0000e-04
# Epoch 15/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9488 - loss: 0.1740 - val_accuracy: 0.9525 - val_loss: 0.1642 - learning_rate: 5.0000e-04
# Epoch 16/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9494 - loss: 0.1683 - val_accuracy: 0.9536 - val_loss: 0.1689 - learning_rate: 5.0000e-04
# Epoch 17/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9519 - loss: 0.1586 - val_accuracy: 0.9470 - val_loss: 0.1941 - learning_rate: 5.0000e-04
# Epoch 18/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9545 - loss: 0.1501 - val_accuracy: 0.9545 - val_loss: 0.1614 - learning_rate: 5.0000e-04
# Epoch 19/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9576 - loss: 0.1410 - val_accuracy: 0.9541 - val_loss: 0.1685 - learning_rate: 5.0000e-04
# Epoch 20/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.9554 - loss: 0.1422 - val_accuracy: 0.9502 - val_loss: 0.1878 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 18.
# Metadata for seed 2025 saved to /kaggle/working/residual_cnn/metadata_residual_cnn_seed_2025.json

# %%
best_model = load_model(best_seed_checkpoint_path)

best_model.summary()
# Out:
# Model: "functional_10"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 40, 101,   │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 40, 101,   │        320 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 40, 101,   │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 40, 101,   │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 40, 101,   │      9,248 │ re_lu[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 101,   │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 40, 101,   │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 40, 101,   │      9,248 │ re_lu_1[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 101,   │        128 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 40, 101,   │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ re_lu[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 40, 101,   │          0 │ add[0][0]         │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 20, 51,    │     18,496 │ re_lu_2[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 51,    │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 20, 51,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 20, 51,    │     36,928 │ re_lu_3[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 20, 51,    │      2,112 │ re_lu_2[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 51,    │        256 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 51,    │        256 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 20, 51,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 20, 51,    │          0 │ add_1[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 10, 26,    │     73,856 │ re_lu_4[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 26,    │        512 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 10, 26,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 10, 26,    │    147,584 │ re_lu_5[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 10, 26,    │      8,320 │ re_lu_4[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 26,    │        512 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 26,    │        512 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 10, 26,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 10, 26,    │          0 │ add_2[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ feature_embedding   │ (None, 128)       │          0 │ re_lu_6[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ feature_embeddin… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 35)        │      4,515 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 937,259 (3.58 MB)
#  Trainable params: 311,971 (1.19 MB)
#  Non-trainable params: 1,344 (5.25 KB)
#  Optimizer params: 623,944 (2.38 MB)

# %%
val_loss, val_acc = best_model.evaluate(val_ds)

test_loss, test_acc = best_model.evaluate(test_ds)

print(f"\nValidation accuracy: {val_acc:.4f}")
print(f"Validation loss: {val_loss:.4f}")

print(f"\nTest accuracy: {test_acc:.4f}")
print(f"Test loss: {test_loss:.4f}")
# Out:
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9605 - loss: 0.1400
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9545 - loss: 0.1544
#
# Validation accuracy: 0.9572
# Validation loss: 0.1532
#
# Test accuracy: 0.9537
# Test loss: 0.1574

# %%
save_and_plot_results(history, best_model, model_name, saving_dir)
# Out:
# --- Saving results for model: residual_cnn ---
# Loss plot saved to /kaggle/working/residual_cnn/residual_cnn_loss.png
# Accuracy plot saved to /kaggle/working/residual_cnn/residual_cnn_accuracy.png
# Training history saved to /kaggle/working/residual_cnn/training_history.pkl
#
# --- Plotting model architecture for: residual_cnn ---
# Model architecture plot saved

# %% [markdown]
# ## Hybrid CNN + BiLSTM
#
# Hybrid model that combines a CNN frontend with a BiLSTM backend.

# %%
class CNNBiLSTMModel:
    def __init__(self, input_shape=(40, 101, 1), num_classes=12,
                 lstm_units=32, dense_units=64, dropout_rate=0.3):
        self.input_shape = input_shape
        self.num_classes = num_classes
        self.lstm_units = lstm_units
        self.dense_units = dense_units
        self.dropout_rate = dropout_rate
        self.model = self._build_model()

    def _build_model(self):
        inputs = tf.keras.Input(shape=self.input_shape)

        # CNN Layers
        x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
        x = layers.BatchNormalization()(x)
        x = layers.MaxPooling2D(pool_size=(2, 2))(x)

        x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = layers.MaxPooling2D(pool_size=(2, 2))(x) 

        # Reshape
        x = layers.Permute((2, 1, 3))(x)
        current_shape = x.shape
        x = layers.Reshape((current_shape[1], current_shape[2] * current_shape[3]))(x)

        # Feature Compression
        x = layers.TimeDistributed(layers.Dense(128, activation='relu'))(x)

        # BiLSTM with return_sequences
        x = layers.Bidirectional(
            layers.LSTM(self.lstm_units, return_sequences=True)
        )(x)

        # Pooling across time
        x = layers.GlobalAveragePooling1D()(x)

        # Dropout + Classifier
        x = layers.Dropout(self.dropout_rate)(x)
        x = layers.Dense(self.dense_units, activation='relu', name="feature_embedding")(x)
        x = layers.Dropout(self.dropout_rate)(x)
        outputs = layers.Dense(self.num_classes, activation='softmax')(x)

        return models.Model(inputs, outputs)

    def compile(self, learning_rate=0.001):
        self.model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy']
        )

    def get_model(self):
        return self.model

# %%
model_name = "hybrid_cnn_bilstm"
print(f"\nTRAINING MODEL: {model_name.upper()}")

best_seed_history = None
best_seed_val_accuracy = 0.0
best_seed_checkpoint_path = ""

for seed in SEEDS:
    set_seeds(seed)
    print(f"\n--- Training '{model_name}' with Seed: {seed} ---")

    model_instance = CNNBiLSTMModel(input_shape=(40, 101, 1), num_classes=len(label_to_index))
    history, checkpoint_path, saving_dir = train_models(model_name, model_instance, seed)

    current_best_val_acc = max(history.history['val_accuracy'])
    if current_best_val_acc > best_seed_val_accuracy:
        best_seed_val_accuracy = current_best_val_acc
        best_seed_history = history
        best_seed_checkpoint_path = checkpoint_path
# Out:
# TRAINING MODEL: HYBRID_CNN_BILSTM
#
# --- Training 'hybrid_cnn_bilstm' with Seed: 42 ---
# Epoch 1/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 41s 23ms/step - accuracy: 0.2503 - loss: 2.7062 - val_accuracy: 0.8091 - val_loss: 0.6735 - learning_rate: 0.0010
# Epoch 2/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.7203 - loss: 0.9693 - val_accuracy: 0.8800 - val_loss: 0.4134 - learning_rate: 0.0010
# Epoch 3/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.8108 - loss: 0.6615 - val_accuracy: 0.9028 - val_loss: 0.3454 - learning_rate: 0.0010
# Epoch 4/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.8469 - loss: 0.5321 - val_accuracy: 0.9235 - val_loss: 0.2656 - learning_rate: 0.0010
# Epoch 5/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.8657 - loss: 0.4686 - val_accuracy: 0.9257 - val_loss: 0.2665 - learning_rate: 0.0010
# Epoch 6/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.8826 - loss: 0.4075 - val_accuracy: 0.9248 - val_loss: 0.2599 - learning_rate: 0.0010
# Epoch 7/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.8915 - loss: 0.3785 - val_accuracy: 0.9231 - val_loss: 0.2530 - learning_rate: 0.0010
# Epoch 8/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.9022 - loss: 0.3393 - val_accuracy: 0.9328 - val_loss: 0.2400 - learning_rate: 0.0010
# Epoch 9/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.9064 - loss: 0.3201 - val_accuracy: 0.9360 - val_loss: 0.2329 - learning_rate: 0.0010
# Epoch 10/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.9170 - loss: 0.2855 - val_accuracy: 0.9394 - val_loss: 0.2199 - learning_rate: 0.0010
# Epoch 11/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.9165 - loss: 0.2818 - val_accuracy: 0.9382 - val_loss: 0.2340 - learning_rate: 0.0010
# Epoch 12/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.9244 - loss: 0.2625 - val_accuracy: 0.9408 - val_loss: 0.2113 - learning_rate: 0.0010
# Epoch 13/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.9258 - loss: 0.2528 - val_accuracy: 0.9407 - val_loss: 0.2150 - learning_rate: 0.0010
# Epoch 14/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.9300 - loss: 0.2348 - val_accuracy: 0.9455 - val_loss: 0.2065 - learning_rate: 0.0010
# Epoch 15/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.9341 - loss: 0.2228 - val_accuracy: 0.9438 - val_loss: 0.2197 - learning_rate: 0.0010
# Epoch 16/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.9357 - loss: 0.2119 - val_accuracy: 0.9418 - val_loss: 0.2223 - learning_rate: 0.0010
# Epoch 17/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.9375 - loss: 0.2133 - val_accuracy: 0.9457 - val_loss: 0.2062 - learning_rate: 0.0010
# Epoch 18/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.9395 - loss: 0.2000 - val_accuracy: 0.9431 - val_loss: 0.2157 - learning_rate: 0.0010
# Epoch 19/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.9424 - loss: 0.1888 - val_accuracy: 0.9469 - val_loss: 0.2145 - learning_rate: 0.0010
# Epoch 20/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9442 - loss: 0.1872
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.9442 - loss: 0.1872 - val_accuracy: 0.9416 - val_loss: 0.2313 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 17.
# Metadata for seed 42 saved to /kaggle/working/hybrid_cnn_bilstm/metadata_hybrid_cnn_bilstm_seed_42.json
#
# --- Training 'hybrid_cnn_bilstm' with Seed: 1999 ---
# Epoch 1/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 40s 23ms/step - accuracy: 0.2744 - loss: 2.5911 - val_accuracy: 0.8061 - val_loss: 0.6481 - learning_rate: 0.0010
# Epoch 2/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.7283 - loss: 0.9285 - val_accuracy: 0.8700 - val_loss: 0.4553 - learning_rate: 0.0010
# Epoch 3/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.8150 - loss: 0.6503 - val_accuracy: 0.9128 - val_loss: 0.3053 - learning_rate: 0.0010
# Epoch 4/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.8511 - loss: 0.5263 - val_accuracy: 0.9166 - val_loss: 0.2924 - learning_rate: 0.0010
# Epoch 5/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 21ms/step - accuracy: 0.8701 - loss: 0.4620 - val_accuracy: 0.9230 - val_loss: 0.2721 - learning_rate: 0.0010
# Epoch 6/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 21ms/step - accuracy: 0.8830 - loss: 0.4108 - val_accuracy: 0.9330 - val_loss: 0.2317 - learning_rate: 0.0010
# Epoch 7/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.8923 - loss: 0.3718 - val_accuracy: 0.9359 - val_loss: 0.2401 - learning_rate: 0.0010
# Epoch 8/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 21ms/step - accuracy: 0.9015 - loss: 0.3441 - val_accuracy: 0.9356 - val_loss: 0.2317 - learning_rate: 0.0010
# Epoch 9/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9066 - loss: 0.3242
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.9066 - loss: 0.3242 - val_accuracy: 0.9258 - val_loss: 0.2709 - learning_rate: 0.0010
# Epoch 10/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.9231 - loss: 0.2618 - val_accuracy: 0.9408 - val_loss: 0.2105 - learning_rate: 5.0000e-04
# Epoch 11/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.9303 - loss: 0.2335 - val_accuracy: 0.9429 - val_loss: 0.2090 - learning_rate: 5.0000e-04
# Epoch 12/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.9338 - loss: 0.2215 - val_accuracy: 0.9440 - val_loss: 0.1985 - learning_rate: 5.0000e-04
# Epoch 13/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.9368 - loss: 0.2104 - val_accuracy: 0.9457 - val_loss: 0.2158 - learning_rate: 5.0000e-04
# Epoch 14/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.9409 - loss: 0.1974 - val_accuracy: 0.9454 - val_loss: 0.2184 - learning_rate: 5.0000e-04
# Epoch 15/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9432 - loss: 0.1852
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.9432 - loss: 0.1852 - val_accuracy: 0.9455 - val_loss: 0.2132 - learning_rate: 5.0000e-04
# Epoch 16/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.9504 - loss: 0.1635 - val_accuracy: 0.9483 - val_loss: 0.2102 - learning_rate: 2.5000e-04
# Epoch 17/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.9549 - loss: 0.1482 - val_accuracy: 0.9481 - val_loss: 0.2113 - learning_rate: 2.5000e-04
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Metadata for seed 1999 saved to /kaggle/working/hybrid_cnn_bilstm/metadata_hybrid_cnn_bilstm_seed_1999.json
#
# --- Training 'hybrid_cnn_bilstm' with Seed: 2025 ---
# Epoch 1/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 39s 23ms/step - accuracy: 0.2698 - loss: 2.6268 - val_accuracy: 0.8131 - val_loss: 0.6744 - learning_rate: 0.0010
# Epoch 2/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.7154 - loss: 0.9804 - val_accuracy: 0.8846 - val_loss: 0.4037 - learning_rate: 0.0010
# Epoch 3/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.8047 - loss: 0.6765 - val_accuracy: 0.9050 - val_loss: 0.3307 - learning_rate: 0.0010
# Epoch 4/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.8414 - loss: 0.5513 - val_accuracy: 0.9112 - val_loss: 0.3019 - learning_rate: 0.0010
# Epoch 5/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.8606 - loss: 0.4865 - val_accuracy: 0.9157 - val_loss: 0.2870 - learning_rate: 0.0010
# Epoch 6/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.8777 - loss: 0.4290 - val_accuracy: 0.9305 - val_loss: 0.2447 - learning_rate: 0.0010
# Epoch 7/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.8884 - loss: 0.3906 - val_accuracy: 0.9307 - val_loss: 0.2440 - learning_rate: 0.0010
# Epoch 8/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.8943 - loss: 0.3585 - val_accuracy: 0.9269 - val_loss: 0.2482 - learning_rate: 0.0010
# Epoch 9/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.9044 - loss: 0.3315 - val_accuracy: 0.9370 - val_loss: 0.2223 - learning_rate: 0.0010
# Epoch 10/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.9086 - loss: 0.3112 - val_accuracy: 0.9423 - val_loss: 0.2066 - learning_rate: 0.0010
# Epoch 11/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.9154 - loss: 0.2848 - val_accuracy: 0.9452 - val_loss: 0.2090 - learning_rate: 0.0010
# Epoch 12/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.9200 - loss: 0.2729 - val_accuracy: 0.9449 - val_loss: 0.2095 - learning_rate: 0.0010
# Epoch 13/20
# 1324/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9266 - loss: 0.2495
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.9265 - loss: 0.2496 - val_accuracy: 0.9409 - val_loss: 0.2210 - learning_rate: 0.0010
# Epoch 14/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.9355 - loss: 0.2165 - val_accuracy: 0.9498 - val_loss: 0.1963 - learning_rate: 5.0000e-04
# Epoch 15/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.9426 - loss: 0.1886 - val_accuracy: 0.9479 - val_loss: 0.2092 - learning_rate: 5.0000e-04
# Epoch 16/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.9465 - loss: 0.1794 - val_accuracy: 0.9491 - val_loss: 0.2109 - learning_rate: 5.0000e-04
# Epoch 17/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9491 - loss: 0.1698
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.9491 - loss: 0.1698 - val_accuracy: 0.9463 - val_loss: 0.2280 - learning_rate: 5.0000e-04
# Epoch 18/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.9544 - loss: 0.1523 - val_accuracy: 0.9491 - val_loss: 0.2256 - learning_rate: 2.5000e-04
# Epoch 19/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 29s 22ms/step - accuracy: 0.9598 - loss: 0.1300 - val_accuracy: 0.9508 - val_loss: 0.2200 - learning_rate: 2.5000e-04
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Metadata for seed 2025 saved to /kaggle/working/hybrid_cnn_bilstm/metadata_hybrid_cnn_bilstm_seed_2025.json

# %%
best_model = load_model(best_seed_checkpoint_path)

best_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 40, 101, 1)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 40, 101, 32)    │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 40, 101, 32)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 20, 50, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 20, 50, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 20, 50, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 10, 25, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ permute (Permute)               │ (None, 25, 10, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 25, 640)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 25, 128)        │        82,048 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 25, 64)         │        41,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ feature_embedding (Dense)       │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 35)             │         2,275 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 446,315 (1.70 MB)
#  Trainable params: 148,707 (580.89 KB)
#  Non-trainable params: 192 (768.00 B)
#  Optimizer params: 297,416 (1.13 MB)

# %%
val_loss, val_acc = best_model.evaluate(val_ds)

test_loss, test_acc = best_model.evaluate(test_ds)

print(f"\nValidation accuracy: {val_acc:.4f}")
print(f"Validation loss: {val_loss:.4f}")

print(f"\nTest accuracy: {test_acc:.4f}")
print(f"Test loss: {test_loss:.4f}")
# Out:
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9536 - loss: 0.2084
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9499 - loss: 0.2111
#
# Validation accuracy: 0.9508
# Validation loss: 0.2200
#
# Test accuracy: 0.9485
# Test loss: 0.2070

# %%
save_and_plot_results(history, best_model, model_name, saving_dir, transformer = True)
# Out:
# --- Saving results for model: hybrid_cnn_bilstm ---
# Loss plot saved to /kaggle/working/hybrid_cnn_bilstm/hybrid_cnn_bilstm_loss.png
# Accuracy plot saved to /kaggle/working/hybrid_cnn_bilstm/hybrid_cnn_bilstm_accuracy.png
# Training history saved to /kaggle/working/hybrid_cnn_bilstm/training_history.pkl

# %% [markdown]
# ## Hybrid CNN + Transformer
#
# Hybrid model that combines a CNN frontend with a Transformer backend.

# %%
def transformer_encoder_block(embed_dim, num_heads, ff_dim, dropout_rate=0.1):
    inputs = layers.Input(shape=(None, embed_dim))
    
    # Multi-Head Attention
    attention_output = layers.MultiHeadAttention(
        num_heads=num_heads, key_dim=embed_dim
    )(inputs, inputs)
    attention_output = layers.Dropout(dropout_rate)(attention_output)
    out1 = layers.LayerNormalization(epsilon=1e-6)(inputs + attention_output)

    # Feed-Forward Network
    ffn_output = layers.Dense(ff_dim, activation="relu")(out1)
    ffn_output = layers.Dense(embed_dim)(ffn_output)
    ffn_output = layers.Dropout(dropout_rate)(ffn_output)
    out2 = layers.LayerNormalization(epsilon=1e-6)(out1 + ffn_output)
    
    return models.Model(inputs=inputs, outputs=out2)

@register_keras_serializable()
class PositionalEncoding(layers.Layer):
    def __init__(self, max_steps, max_dims, **kwargs):
        super().__init__(**kwargs)
        self.max_steps = max_steps
        self.max_dims = max_dims
        self.positional_encoding = self.build_pe(max_steps, max_dims)

    def build_pe(self, max_steps, max_dims):
        pe = np.zeros((max_steps, max_dims))
        position = np.arange(0, max_steps, dtype=np.float32).reshape(-1, 1)
        div_term = np.exp(np.arange(0, max_dims, 2, dtype=np.float32) * -(np.log(10000.0) / max_dims))
        pe[:, 0::2] = np.sin(position * div_term)
        pe[:, 1::2] = np.cos(position * div_term)
        return tf.constant(pe, dtype=tf.float32)

    def call(self, inputs):
        return inputs + self.positional_encoding

    def get_config(self):
        config = super().get_config()
        config.update({
            "max_steps": self.max_steps,
            "max_dims": self.max_dims,
        })
        return config

# %%
class HybridCNNTransformerModel:
    def __init__(self, input_shape=(40, 101, 1), num_classes=len(label_to_index),
                 num_transformer_blocks=2, embed_dim=64, num_heads=4, ff_dim=64, dropout_rate=0.2):
        self.input_shape = input_shape
        self.num_classes = num_classes
        self.num_transformer_blocks = num_transformer_blocks
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.ff_dim = ff_dim
        self.dropout_rate = dropout_rate
        self.model = self._build_model()

    def _build_model(self):
        inputs = layers.Input(shape=self.input_shape)

        # Convolutional Feature Extractor
        x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
        x = layers.BatchNormalization()(x)
        x = layers.MaxPooling2D((2, 2))(x)

        x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = layers.MaxPooling2D((2, 2))(x)

        # Reshape to a sequence
        x = layers.Permute((2, 1, 3))(x)
        x = layers.Reshape((x.shape[1], -1))(x)
        
        # Project to the Transformer's embedding dimension
        x = layers.Dense(self.embed_dim)(x)
        
        # Add Positional Encoding
        x = PositionalEncoding(max_steps=x.shape[1], max_dims=self.embed_dim)(x)

        # Transformer Encoder Blocks
        for _ in range(self.num_transformer_blocks):
            encoder = transformer_encoder_block(self.embed_dim, self.num_heads, self.ff_dim, self.dropout_rate)
            x = encoder(x)
        
        # Classifier Head
        x = layers.GlobalAveragePooling1D()(x)
        x = layers.Dropout(self.dropout_rate)(x)
        x = layers.Dense(self.ff_dim, activation='relu', name="feature_embedding")(x)
        x = layers.Dropout(self.dropout_rate)(x)
        outputs = layers.Dense(self.num_classes, activation='softmax')(x)

        return models.Model(inputs=inputs, outputs=outputs)

    def compile(self, optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy']):
        self.model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

    def get_model(self):
        return self.model

# %%
model_name = "hybrid_cnn_transformer"
print(f"\nTRAINING MODEL: {model_name.upper()}")

best_seed_history = None
best_seed_val_accuracy = 0.0
best_seed_checkpoint_path = ""

for seed in SEEDS:
    set_seeds(seed)
    print(f"\n--- Training '{model_name}' with Seed: {seed} ---")

    model_instance = HybridCNNTransformerModel(input_shape=(40, 101, 1), num_classes=len(label_to_index))
    history, checkpoint_path, saving_dir = train_models(model_name, model_instance, seed)

    current_best_val_acc = max(history.history['val_accuracy'])
    if current_best_val_acc > best_seed_val_accuracy:
        best_seed_val_accuracy = current_best_val_acc
        best_seed_history = history
        best_seed_checkpoint_path = checkpoint_path
# Out:
# TRAINING MODEL: HYBRID_CNN_TRANSFORMER
#
# --- Training 'hybrid_cnn_transformer' with Seed: 42 ---
# Epoch 1/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 45s 18ms/step - accuracy: 0.3147 - loss: 2.4025 - val_accuracy: 0.8252 - val_loss: 0.5584 - learning_rate: 0.0010
# Epoch 2/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.7528 - loss: 0.8506 - val_accuracy: 0.8498 - val_loss: 0.5127 - learning_rate: 0.0010
# Epoch 3/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.7942 - loss: 0.7164 - val_accuracy: 0.8233 - val_loss: 0.6122 - learning_rate: 0.0010
# Epoch 4/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.8108 - loss: 0.6476 - val_accuracy: 0.9017 - val_loss: 0.3367 - learning_rate: 0.0010
# Epoch 5/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.8254 - loss: 0.6088 - val_accuracy: 0.8981 - val_loss: 0.3389 - learning_rate: 0.0010
# Epoch 6/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.8358 - loss: 0.5717 - val_accuracy: 0.9025 - val_loss: 0.3139 - learning_rate: 0.0010
# Epoch 7/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.8364 - loss: 0.5770 - val_accuracy: 0.9000 - val_loss: 0.3225 - learning_rate: 0.0010
# Epoch 8/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8493 - loss: 0.5327 - val_accuracy: 0.9051 - val_loss: 0.3192 - learning_rate: 0.0010
# Epoch 9/20
# 1324/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8386 - loss: 0.5677
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.8386 - loss: 0.5677 - val_accuracy: 0.8920 - val_loss: 0.3651 - learning_rate: 0.0010
# Epoch 10/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8730 - loss: 0.4447 - val_accuracy: 0.9070 - val_loss: 0.3268 - learning_rate: 5.0000e-04
# Epoch 11/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8765 - loss: 0.4245 - val_accuracy: 0.9213 - val_loss: 0.2669 - learning_rate: 5.0000e-04
# Epoch 12/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.8870 - loss: 0.3917 - val_accuracy: 0.9289 - val_loss: 0.2491 - learning_rate: 5.0000e-04
# Epoch 13/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.8903 - loss: 0.3813 - val_accuracy: 0.9256 - val_loss: 0.2577 - learning_rate: 5.0000e-04
# Epoch 14/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8965 - loss: 0.3628 - val_accuracy: 0.9228 - val_loss: 0.2653 - learning_rate: 5.0000e-04
# Epoch 15/20
# 1321/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8963 - loss: 0.3580
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.8963 - loss: 0.3579 - val_accuracy: 0.9146 - val_loss: 0.2875 - learning_rate: 5.0000e-04
# Epoch 16/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.9079 - loss: 0.3181 - val_accuracy: 0.9377 - val_loss: 0.2166 - learning_rate: 2.5000e-04
# Epoch 17/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.9156 - loss: 0.2885 - val_accuracy: 0.9386 - val_loss: 0.2189 - learning_rate: 2.5000e-04
# Epoch 18/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.9188 - loss: 0.2809 - val_accuracy: 0.9416 - val_loss: 0.2064 - learning_rate: 2.5000e-04
# Epoch 19/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.9197 - loss: 0.2754 - val_accuracy: 0.9417 - val_loss: 0.2123 - learning_rate: 2.5000e-04
# Epoch 20/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.9240 - loss: 0.2621 - val_accuracy: 0.9430 - val_loss: 0.2046 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 20.
# Metadata for seed 42 saved to /kaggle/working/hybrid_cnn_transformer/metadata_hybrid_cnn_transformer_seed_42.json
#
# --- Training 'hybrid_cnn_transformer' with Seed: 1999 ---
# Epoch 1/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 43s 17ms/step - accuracy: 0.3189 - loss: 2.3845 - val_accuracy: 0.7882 - val_loss: 0.7030 - learning_rate: 0.0010
# Epoch 2/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.7305 - loss: 0.9336 - val_accuracy: 0.8614 - val_loss: 0.4685 - learning_rate: 0.0010
# Epoch 3/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.7857 - loss: 0.7396 - val_accuracy: 0.7925 - val_loss: 0.6967 - learning_rate: 0.0010
# Epoch 4/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8005 - loss: 0.7005 - val_accuracy: 0.8788 - val_loss: 0.4051 - learning_rate: 0.0010
# Epoch 5/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8156 - loss: 0.6480 - val_accuracy: 0.8652 - val_loss: 0.4497 - learning_rate: 0.0010
# Epoch 6/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.8188 - loss: 0.6301 - val_accuracy: 0.8494 - val_loss: 0.4914 - learning_rate: 0.0010
# Epoch 7/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.8165 - loss: 0.6414 - val_accuracy: 0.8915 - val_loss: 0.3544 - learning_rate: 0.0010
# Epoch 8/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8426 - loss: 0.5549 - val_accuracy: 0.8967 - val_loss: 0.3463 - learning_rate: 0.0010
# Epoch 9/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8465 - loss: 0.5419 - val_accuracy: 0.9008 - val_loss: 0.3325 - learning_rate: 0.0010
# Epoch 10/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8468 - loss: 0.5330 - val_accuracy: 0.9082 - val_loss: 0.3160 - learning_rate: 0.0010
# Epoch 11/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8483 - loss: 0.5312 - val_accuracy: 0.9022 - val_loss: 0.3276 - learning_rate: 0.0010
# Epoch 12/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8488 - loss: 0.5291 - val_accuracy: 0.8450 - val_loss: 0.5316 - learning_rate: 0.0010
# Epoch 13/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8325 - loss: 0.5955 - val_accuracy: 0.9106 - val_loss: 0.3039 - learning_rate: 0.0010
# Epoch 14/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8529 - loss: 0.5214 - val_accuracy: 0.9182 - val_loss: 0.2784 - learning_rate: 0.0010
# Epoch 15/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8645 - loss: 0.4744 - val_accuracy: 0.9081 - val_loss: 0.3253 - learning_rate: 0.0010
# Epoch 16/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.8614 - loss: 0.4825 - val_accuracy: 0.9170 - val_loss: 0.2855 - learning_rate: 0.0010
# Epoch 17/20
# 1323/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8648 - loss: 0.4751
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.8648 - loss: 0.4752 - val_accuracy: 0.9052 - val_loss: 0.3300 - learning_rate: 0.0010
# Epoch 18/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8799 - loss: 0.4284 - val_accuracy: 0.9313 - val_loss: 0.2352 - learning_rate: 5.0000e-04
# Epoch 19/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.8922 - loss: 0.3736 - val_accuracy: 0.9284 - val_loss: 0.2387 - learning_rate: 5.0000e-04
# Epoch 20/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8952 - loss: 0.3651 - val_accuracy: 0.9346 - val_loss: 0.2283 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 20.
# Metadata for seed 1999 saved to /kaggle/working/hybrid_cnn_transformer/metadata_hybrid_cnn_transformer_seed_1999.json
#
# --- Training 'hybrid_cnn_transformer' with Seed: 2025 ---
# Epoch 1/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 44s 17ms/step - accuracy: 0.3197 - loss: 2.4061 - val_accuracy: 0.8239 - val_loss: 0.6007 - learning_rate: 0.0010
# Epoch 2/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.7418 - loss: 0.8894 - val_accuracy: 0.8386 - val_loss: 0.5220 - learning_rate: 0.0010
# Epoch 3/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.7867 - loss: 0.7406 - val_accuracy: 0.8798 - val_loss: 0.4015 - learning_rate: 0.0010
# Epoch 4/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8099 - loss: 0.6681 - val_accuracy: 0.8409 - val_loss: 0.5051 - learning_rate: 0.0010
# Epoch 5/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.7913 - loss: 0.7362 - val_accuracy: 0.8796 - val_loss: 0.4166 - learning_rate: 0.0010
# Epoch 6/20
# 1322/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8257 - loss: 0.6023
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8257 - loss: 0.6023 - val_accuracy: 0.8768 - val_loss: 0.4206 - learning_rate: 0.0010
# Epoch 7/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8504 - loss: 0.5217 - val_accuracy: 0.9151 - val_loss: 0.2803 - learning_rate: 5.0000e-04
# Epoch 8/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8624 - loss: 0.4762 - val_accuracy: 0.9190 - val_loss: 0.2768 - learning_rate: 5.0000e-04
# Epoch 9/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8721 - loss: 0.4390 - val_accuracy: 0.9117 - val_loss: 0.2999 - learning_rate: 5.0000e-04
# Epoch 10/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8745 - loss: 0.4325 - val_accuracy: 0.9273 - val_loss: 0.2487 - learning_rate: 5.0000e-04
# Epoch 11/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8774 - loss: 0.4229 - val_accuracy: 0.9282 - val_loss: 0.2487 - learning_rate: 5.0000e-04
# Epoch 12/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8806 - loss: 0.4153 - val_accuracy: 0.9225 - val_loss: 0.2657 - learning_rate: 5.0000e-04
# Epoch 13/20
# 1325/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8804 - loss: 0.4113
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8804 - loss: 0.4113 - val_accuracy: 0.9199 - val_loss: 0.2703 - learning_rate: 5.0000e-04
# Epoch 14/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.8952 - loss: 0.3620 - val_accuracy: 0.9360 - val_loss: 0.2344 - learning_rate: 2.5000e-04
# Epoch 15/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.9035 - loss: 0.3306 - val_accuracy: 0.9377 - val_loss: 0.2187 - learning_rate: 2.5000e-04
# Epoch 16/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.9057 - loss: 0.3201 - val_accuracy: 0.9363 - val_loss: 0.2250 - learning_rate: 2.5000e-04
# Epoch 17/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.9105 - loss: 0.3051 - val_accuracy: 0.9367 - val_loss: 0.2208 - learning_rate: 2.5000e-04
# Epoch 18/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9085 - loss: 0.3072
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.9085 - loss: 0.3072 - val_accuracy: 0.9383 - val_loss: 0.2205 - learning_rate: 2.5000e-04
# Epoch 19/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.9168 - loss: 0.2836 - val_accuracy: 0.9441 - val_loss: 0.2060 - learning_rate: 1.2500e-04
# Epoch 20/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.9202 - loss: 0.2728 - val_accuracy: 0.9445 - val_loss: 0.2006 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 20.
# Metadata for seed 2025 saved to /kaggle/working/hybrid_cnn_transformer/metadata_hybrid_cnn_transformer_seed_2025.json

# %%
best_model = load_model(best_seed_checkpoint_path)

best_model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 40, 101, 1)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 40, 101, 32)    │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 40, 101, 32)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 20, 50, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 20, 50, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 20, 50, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 10, 25, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ permute (Permute)               │ (None, 25, 10, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 25, 640)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 25, 64)         │        41,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ positional_encoding             │ (None, 25, 64)         │             0 │
# │ (PositionalEncoding)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional (Functional)         │ (None, 25, 64)         │        74,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_1 (Functional)       │ (None, 25, 64)         │        74,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ feature_embedding (Dense)       │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 35)             │         2,275 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 649,259 (2.48 MB)
#  Trainable params: 216,355 (845.14 KB)
#  Non-trainable params: 192 (768.00 B)
#  Optimizer params: 432,712 (1.65 MB)

# %%
val_loss, val_acc = best_model.evaluate(val_ds)

test_loss, test_acc = best_model.evaluate(test_ds)

print(f"\nValidation accuracy: {val_acc:.4f}")
print(f"Validation loss: {val_loss:.4f}")

print(f"\nTest accuracy: {test_acc:.4f}")
print(f"Test loss: {test_loss:.4f}")
# Out:
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9466 - loss: 0.1876
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9456 - loss: 0.2046
#
# Validation accuracy: 0.9445
# Validation loss: 0.2006
#
# Test accuracy: 0.9420
# Test loss: 0.2154

# %%
save_and_plot_results(history, best_model, model_name, saving_dir, transformer = True)
# Out:
# --- Saving results for model: hybrid_cnn_transformer ---
# Loss plot saved to /kaggle/working/hybrid_cnn_transformer/hybrid_cnn_transformer_loss.png
# Accuracy plot saved to /kaggle/working/hybrid_cnn_transformer/hybrid_cnn_transformer_accuracy.png
# Training history saved to /kaggle/working/hybrid_cnn_transformer/training_history.pkl

# %% [markdown]
# ## Vision Transformer (ViT)

# %%
@register_keras_serializable()
class Patches(layers.Layer):
    """Splits an image into patches."""
    def __init__(self, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches
    def get_config(self):
        config = super().get_config()
        config.update({"patch_size": self.patch_size})
        return config
    

@register_keras_serializable()
class PatchEncoder(layers.Layer):
    """Encodes patches with a projection and positional embedding."""
    def __init__(self, num_patches, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.embed_dim = embed_dim
        
    def build(self, input_shape):
        self.projection = layers.Dense(units=self.embed_dim)
        self.positional_embedding = layers.Embedding(
            input_dim=self.num_patches, output_dim=self.embed_dim
        )
        super().build(input_shape)

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.positional_embedding(positions)
        return encoded
        
    def get_config(self):
        config = super().get_config()
        config.update({
            "num_patches": self.num_patches,
            "embed_dim": self.embed_dim,
        })
        return config

# %%
class VisionTransformerModel:
    def __init__(self, input_shape=(40, 101, 1), num_classes=len(label_to_index),
                 patch_size=8, num_transformer_blocks=2, embed_dim=64, 
                 num_heads=4, ff_dim=64, dropout_rate=0.2):
        self.input_shape = input_shape
        self.num_classes = num_classes
        self.patch_size = patch_size
        self.num_transformer_blocks = num_transformer_blocks
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.ff_dim = ff_dim
        self.dropout_rate = dropout_rate
        self.model = self._build_model()

    def _build_model(self):
        inputs = layers.Input(shape=self.input_shape)
        
        # Since the input dimensions (40, 101) are not perfectly divisible by patch_size,
        # we first resize to a divisible dimension, e.g., (40, 104) -> divisible by 8
        # Note: 101 is prime, so padding/resizing is needed. I choose 104 as new size.
        resized_input = layers.Resizing(height=40, width=104)(inputs)
        
        # Create Patches
        num_patches = (40 // self.patch_size) * (104 // self.patch_size)
        patches = Patches(self.patch_size)(resized_input)

        # Encode Patches with positional embedding
        encoded_patches = PatchEncoder(num_patches, self.embed_dim)(patches)

        # Transformer Encoder Blocks
        x = encoded_patches
        for _ in range(self.num_transformer_blocks):
            encoder = transformer_encoder_block(self.embed_dim, self.num_heads, self.ff_dim, self.dropout_rate)
            x = encoder(x)
            
        # Classifier Head
        # Global average pooling over the sequence of patches
        x = layers.GlobalAveragePooling1D()(x)
        x = layers.Dropout(self.dropout_rate)(x)
        x = layers.Dense(self.ff_dim, activation='relu', name="feature_embedding")(x)
        x = layers.Dropout(self.dropout_rate)(x)
        outputs = layers.Dense(self.num_classes, activation="softmax")(x)

        return models.Model(inputs=inputs, outputs=outputs)
    
    def compile(self, optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy']):
        self.model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

    def get_model(self):
        return self.model

# %%
model_name = "vision_transformer"
print(f"\nTRAINING MODEL: {model_name.upper()}")

best_seed_history = None
best_seed_val_accuracy = 0.0
best_seed_checkpoint_path = ""

for seed in SEEDS:
    set_seeds(seed)
    print(f"\n--- Training '{model_name}' with Seed: {seed} ---")

    model_instance = VisionTransformerModel(input_shape=(40, 101, 1), num_classes=len(label_to_index))
    history, checkpoint_path, saving_dir = train_models(model_name, model_instance, seed)

    current_best_val_acc = max(history.history['val_accuracy'])
    if current_best_val_acc > best_seed_val_accuracy:
        best_seed_val_accuracy = current_best_val_acc
        best_seed_history = history
        best_seed_checkpoint_path = checkpoint_path
# Out:
# TRAINING MODEL: VISION_TRANSFORMER
#
# --- Training 'vision_transformer' with Seed: 42 ---
# Epoch 1/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 39s 15ms/step - accuracy: 0.0688 - loss: 3.4172 - val_accuracy: 0.3608 - val_loss: 2.1392 - learning_rate: 0.0010
# Epoch 2/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.3318 - loss: 2.2952 - val_accuracy: 0.6283 - val_loss: 1.2408 - learning_rate: 0.0010
# Epoch 3/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.4934 - loss: 1.7336 - val_accuracy: 0.7210 - val_loss: 0.9359 - learning_rate: 0.0010
# Epoch 4/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.5719 - loss: 1.4545 - val_accuracy: 0.7085 - val_loss: 0.9332 - learning_rate: 0.0010
# Epoch 5/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.6142 - loss: 1.3025 - val_accuracy: 0.7560 - val_loss: 0.7984 - learning_rate: 0.0010
# Epoch 6/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.6389 - loss: 1.2133 - val_accuracy: 0.7991 - val_loss: 0.6604 - learning_rate: 0.0010
# Epoch 7/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.6613 - loss: 1.1478 - val_accuracy: 0.8089 - val_loss: 0.6309 - learning_rate: 0.0010
# Epoch 8/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.6846 - loss: 1.0609 - val_accuracy: 0.8102 - val_loss: 0.6161 - learning_rate: 0.0010
# Epoch 9/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.6936 - loss: 1.0221 - val_accuracy: 0.8297 - val_loss: 0.5664 - learning_rate: 0.0010
# Epoch 10/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7074 - loss: 0.9745 - val_accuracy: 0.8300 - val_loss: 0.5471 - learning_rate: 0.0010
# Epoch 11/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7193 - loss: 0.9434 - val_accuracy: 0.8304 - val_loss: 0.5536 - learning_rate: 0.0010
# Epoch 12/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.7259 - loss: 0.9193 - val_accuracy: 0.8202 - val_loss: 0.5917 - learning_rate: 0.0010
# Epoch 13/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.7340 - loss: 0.8835 - val_accuracy: 0.8460 - val_loss: 0.5169 - learning_rate: 0.0010
# Epoch 14/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.7418 - loss: 0.8652 - val_accuracy: 0.8460 - val_loss: 0.5053 - learning_rate: 0.0010
# Epoch 15/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7441 - loss: 0.8500 - val_accuracy: 0.8395 - val_loss: 0.5217 - learning_rate: 0.0010
# Epoch 16/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7506 - loss: 0.8223 - val_accuracy: 0.8512 - val_loss: 0.4984 - learning_rate: 0.0010
# Epoch 17/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7546 - loss: 0.8169 - val_accuracy: 0.8417 - val_loss: 0.5213 - learning_rate: 0.0010
# Epoch 18/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7587 - loss: 0.8012 - val_accuracy: 0.8565 - val_loss: 0.4744 - learning_rate: 0.0010
# Epoch 19/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.7647 - loss: 0.7892 - val_accuracy: 0.8485 - val_loss: 0.4938 - learning_rate: 0.0010
# Epoch 20/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7682 - loss: 0.7772 - val_accuracy: 0.8660 - val_loss: 0.4555 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 20.
# Metadata for seed 42 saved to /kaggle/working/vision_transformer/metadata_vision_transformer_seed_42.json
#
# --- Training 'vision_transformer' with Seed: 1999 ---
# Epoch 1/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 38s 15ms/step - accuracy: 0.0783 - loss: 3.3824 - val_accuracy: 0.4402 - val_loss: 1.8758 - learning_rate: 0.0010
# Epoch 2/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.3604 - loss: 2.1744 - val_accuracy: 0.6228 - val_loss: 1.2010 - learning_rate: 0.0010
# Epoch 3/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.5142 - loss: 1.6453 - val_accuracy: 0.7069 - val_loss: 0.9695 - learning_rate: 0.0010
# Epoch 4/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.5791 - loss: 1.4183 - val_accuracy: 0.7334 - val_loss: 0.8647 - learning_rate: 0.0010
# Epoch 5/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.6232 - loss: 1.2661 - val_accuracy: 0.7663 - val_loss: 0.7526 - learning_rate: 0.0010
# Epoch 6/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.6565 - loss: 1.1523 - val_accuracy: 0.7987 - val_loss: 0.6663 - learning_rate: 0.0010
# Epoch 7/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.6760 - loss: 1.0821 - val_accuracy: 0.8089 - val_loss: 0.6306 - learning_rate: 0.0010
# Epoch 8/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.6954 - loss: 1.0176 - val_accuracy: 0.8092 - val_loss: 0.6166 - learning_rate: 0.0010
# Epoch 9/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.7070 - loss: 0.9762 - val_accuracy: 0.8223 - val_loss: 0.5792 - learning_rate: 0.0010
# Epoch 10/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7198 - loss: 0.9400 - val_accuracy: 0.8130 - val_loss: 0.6081 - learning_rate: 0.0010
# Epoch 11/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7284 - loss: 0.9013 - val_accuracy: 0.8328 - val_loss: 0.5459 - learning_rate: 0.0010
# Epoch 12/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7366 - loss: 0.8767 - val_accuracy: 0.8510 - val_loss: 0.4930 - learning_rate: 0.0010
# Epoch 13/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7466 - loss: 0.8475 - val_accuracy: 0.8457 - val_loss: 0.5153 - learning_rate: 0.0010
# Epoch 14/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.7507 - loss: 0.8377 - val_accuracy: 0.8505 - val_loss: 0.5028 - learning_rate: 0.0010
# Epoch 15/20
# 1323/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7549 - loss: 0.8149
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.7549 - loss: 0.8149 - val_accuracy: 0.8512 - val_loss: 0.5044 - learning_rate: 0.0010
# Epoch 16/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7837 - loss: 0.7174 - val_accuracy: 0.8697 - val_loss: 0.4348 - learning_rate: 5.0000e-04
# Epoch 17/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7943 - loss: 0.6723 - val_accuracy: 0.8772 - val_loss: 0.4134 - learning_rate: 5.0000e-04
# Epoch 18/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.7985 - loss: 0.6754 - val_accuracy: 0.8701 - val_loss: 0.4506 - learning_rate: 5.0000e-04
# Epoch 19/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.8008 - loss: 0.6590 - val_accuracy: 0.8779 - val_loss: 0.4105 - learning_rate: 5.0000e-04
# Epoch 20/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.8034 - loss: 0.6511 - val_accuracy: 0.8793 - val_loss: 0.4072 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 20.
# Metadata for seed 1999 saved to /kaggle/working/vision_transformer/metadata_vision_transformer_seed_1999.json
#
# --- Training 'vision_transformer' with Seed: 2025 ---
# Epoch 1/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 36s 14ms/step - accuracy: 0.0764 - loss: 3.3724 - val_accuracy: 0.3856 - val_loss: 2.0288 - learning_rate: 0.0010
# Epoch 2/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.3351 - loss: 2.2856 - val_accuracy: 0.5649 - val_loss: 1.4138 - learning_rate: 0.0010
# Epoch 3/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.4745 - loss: 1.7790 - val_accuracy: 0.6882 - val_loss: 1.0442 - learning_rate: 0.0010
# Epoch 4/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.5583 - loss: 1.5069 - val_accuracy: 0.7241 - val_loss: 0.9016 - learning_rate: 0.0010
# Epoch 5/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.6035 - loss: 1.3434 - val_accuracy: 0.7594 - val_loss: 0.7881 - learning_rate: 0.0010
# Epoch 6/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.6355 - loss: 1.2265 - val_accuracy: 0.7764 - val_loss: 0.7306 - learning_rate: 0.0010
# Epoch 7/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.6561 - loss: 1.1568 - val_accuracy: 0.7768 - val_loss: 0.7247 - learning_rate: 0.0010
# Epoch 8/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.6743 - loss: 1.0922 - val_accuracy: 0.8115 - val_loss: 0.6168 - learning_rate: 0.0010
# Epoch 9/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.6938 - loss: 1.0211 - val_accuracy: 0.8112 - val_loss: 0.6140 - learning_rate: 0.0010
# Epoch 10/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7036 - loss: 0.9916 - val_accuracy: 0.8241 - val_loss: 0.5731 - learning_rate: 0.0010
# Epoch 11/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7167 - loss: 0.9525 - val_accuracy: 0.8253 - val_loss: 0.5779 - learning_rate: 0.0010
# Epoch 12/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7253 - loss: 0.9149 - val_accuracy: 0.8279 - val_loss: 0.5594 - learning_rate: 0.0010
# Epoch 13/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7331 - loss: 0.8902 - val_accuracy: 0.8367 - val_loss: 0.5537 - learning_rate: 0.0010
# Epoch 14/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.7414 - loss: 0.8658 - val_accuracy: 0.8492 - val_loss: 0.5009 - learning_rate: 0.0010
# Epoch 15/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7463 - loss: 0.8505 - val_accuracy: 0.8432 - val_loss: 0.5087 - learning_rate: 0.0010
# Epoch 16/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7540 - loss: 0.8242 - val_accuracy: 0.8480 - val_loss: 0.5002 - learning_rate: 0.0010
# Epoch 17/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7588 - loss: 0.8054 - val_accuracy: 0.8495 - val_loss: 0.4961 - learning_rate: 0.0010
# Epoch 18/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7593 - loss: 0.8064 - val_accuracy: 0.8617 - val_loss: 0.4663 - learning_rate: 0.0010
# Epoch 19/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7677 - loss: 0.7768 - val_accuracy: 0.8416 - val_loss: 0.5226 - learning_rate: 0.0010
# Epoch 20/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.7717 - loss: 0.7682 - val_accuracy: 0.8516 - val_loss: 0.4879 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 18.
# Metadata for seed 2025 saved to /kaggle/working/vision_transformer/metadata_vision_transformer_seed_2025.json

# %%
best_model = load_model(best_seed_checkpoint_path)

best_model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 40, 101, 1)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resizing (Resizing)             │ (None, 40, 104, 1)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ patches (Patches)               │ (None, None, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ patch_encoder (PatchEncoder)    │ (None, 65, 64)         │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional (Functional)         │ (None, 65, 64)         │        74,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_1 (Functional)       │ (None, 65, 64)         │        74,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ feature_embedding (Dense)       │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 35)             │         2,275 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 493,931 (1.88 MB)
#  Trainable params: 164,643 (643.14 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 329,288 (1.26 MB)

# %%
val_loss, val_acc = best_model.evaluate(val_ds)

test_loss, test_acc = best_model.evaluate(test_ds)

print(f"\nValidation accuracy: {val_acc:.4f}")
print(f"Validation loss: {val_loss:.4f}")

print(f"\nTest accuracy: {test_acc:.4f}")
print(f"Test loss: {test_loss:.4f}")
# Out:
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8890 - loss: 0.3753
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8826 - loss: 0.3915
#
# Validation accuracy: 0.8793
# Validation loss: 0.4072
#
# Test accuracy: 0.8676
# Test loss: 0.4332

# %%
save_and_plot_results(history, best_model, model_name, saving_dir, transformer = True)
# Out:
# --- Saving results for model: vision_transformer ---
# Loss plot saved to /kaggle/working/vision_transformer/vision_transformer_loss.png
# Accuracy plot saved to /kaggle/working/vision_transformer/vision_transformer_accuracy.png
# Training history saved to /kaggle/working/vision_transformer/training_history.pkl

# %% [markdown]
# ## Experimental model
#
# ### **Residual Attention Network with Discriminator-Style Classifier**
#
# Experimental model architecure that combines three different Deep Learning domains:
# 1.  A **ResNet backbone** for robust, hierarchical feature extraction.
# 2.  A **Squeeze-and-Excitation (SE)** block for dynamic, channel-wise feature recalibration.
# 3.  A **classifier inspired by GAN discriminators**, designed to learn a highly robust decision function.

# %%
def squeeze_excite_block(input_tensor, ratio=8):
    """Squeeze-and-Excitation block"""
    init = input_tensor
    channel_axis = -1
    filters = init.shape[channel_axis]
    se_shape = (1, 1, filters)

    se = layers.GlobalAveragePooling2D()(init)
    se = layers.Reshape(se_shape)(se)
    se = layers.Dense(filters // ratio, activation='relu', kernel_initializer='he_normal', use_bias=False)(se)
    se = layers.Dense(filters, activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(se)

    x = layers.multiply([init, se])
    return x

# %%
class ResidualGAN:
    def __init__(self, input_shape=(40, 101, 1), num_classes=label_to_index,
                 dropout_rate=0.4):
        self.input_shape = input_shape
        self.num_classes = num_classes
        self.dropout_rate = dropout_rate
        self.model = self._build_model()

    def _res_block(self, x, filters, stride=1):
        """ Same residual block as the Residual CNN Model"""
        shortcut = x
        x = layers.Conv2D(filters, kernel_size=3, strides=stride, padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = layers.ReLU()(x)
        x = layers.Conv2D(filters, kernel_size=3, strides=1, padding='same')(x)
        x = layers.BatchNormalization()(x)
        if stride != 1 or shortcut.shape[-1] != filters:
            shortcut = layers.Conv2D(filters, kernel_size=1, strides=stride, padding='same')(shortcut)
            shortcut = layers.BatchNormalization()(shortcut)
        x = layers.add([x, shortcut])
        x = layers.ReLU()(x)
        return x

    def _build_model(self):
        inputs = layers.Input(shape=self.input_shape)
        l2_rate = 1e-4

        # Feature Extractor (based on Residual CNN)
        x = layers.Conv2D(32, kernel_size=3, strides=1, padding='same')(inputs)
        x = layers.BatchNormalization()(x)
        x = layers.ReLU()(x)
        
        x = self._res_block(x, 32)
        x = self._res_block(x, 64, stride=2)
        feature_map = self._res_block(x, 128, stride=2)

        # Attention Block
        attention_map = squeeze_excite_block(feature_map)

        # Discriminator-style Classifier
        x = layers.Conv2D(128, kernel_size=3, strides=2, padding='same',
                          kernel_regularizer=regularizers.l2(l2_rate))(attention_map)
        x = layers.LeakyReLU(negative_slope=0.2)(x)
        x = layers.Dropout(self.dropout_rate)(x)

        x = layers.Conv2D(256, kernel_size=3, strides=2, padding='same',
                          kernel_regularizer=regularizers.l2(l2_rate))(x)
        x = layers.LeakyReLU(negative_slope=0.2)(x)
        x = layers.Dropout(self.dropout_rate)(x)

        x = layers.GlobalAveragePooling2D(name="feature_embedding")(x)
        
        outputs = layers.Dense(self.num_classes, activation='softmax',
                               kernel_regularizer=regularizers.l2(l2_rate))(x)

        return models.Model(inputs=inputs, outputs=outputs)

    def compile(self, optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy']):
        self.model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

    def get_model(self):
        return self.model

# %%
model_name = "residual_attention_gan"
print(f"\nTRAINING MODEL: {model_name.upper()}")

best_seed_history = None
best_seed_val_accuracy = 0.0
best_seed_checkpoint_path = ""

for seed in SEEDS:
    set_seeds(seed)
    print(f"\n--- Training '{model_name}' with Seed: {seed} ---")

    model_instance = ResidualGAN(input_shape=(40, 101, 1), num_classes=len(label_to_index))
    history, checkpoint_path, saving_dir = train_models(model_name, model_instance, seed)

    current_best_val_acc = max(history.history['val_accuracy'])
    if current_best_val_acc > best_seed_val_accuracy:
        best_seed_val_accuracy = current_best_val_acc
        best_seed_history = history
        best_seed_checkpoint_path = checkpoint_path
# Out:
# TRAINING MODEL: RESIDUAL_ATTENTION_GAN
#
# --- Training 'residual_attention_gan' with Seed: 42 ---
# Epoch 1/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 66s 34ms/step - accuracy: 0.4825 - loss: 1.8650 - val_accuracy: 0.8507 - val_loss: 0.5865 - learning_rate: 0.0010
# Epoch 2/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 36s 27ms/step - accuracy: 0.8476 - loss: 0.5951 - val_accuracy: 0.9026 - val_loss: 0.4140 - learning_rate: 0.0010
# Epoch 3/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 36s 27ms/step - accuracy: 0.8808 - loss: 0.4874 - val_accuracy: 0.9316 - val_loss: 0.3269 - learning_rate: 0.0010
# Epoch 4/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 36s 27ms/step - accuracy: 0.9032 - loss: 0.4254 - val_accuracy: 0.9322 - val_loss: 0.3281 - learning_rate: 0.0010
# Epoch 5/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9120 - loss: 0.3978 - val_accuracy: 0.9193 - val_loss: 0.3679 - learning_rate: 0.0010
# Epoch 6/20
# 1325/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9174 - loss: 0.3755
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9174 - loss: 0.3755 - val_accuracy: 0.9299 - val_loss: 0.3370 - learning_rate: 0.0010
# Epoch 7/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 36s 27ms/step - accuracy: 0.9405 - loss: 0.2999 - val_accuracy: 0.9507 - val_loss: 0.2532 - learning_rate: 5.0000e-04
# Epoch 8/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 36s 27ms/step - accuracy: 0.9481 - loss: 0.2631 - val_accuracy: 0.9456 - val_loss: 0.2839 - learning_rate: 5.0000e-04
# Epoch 9/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 36s 27ms/step - accuracy: 0.9522 - loss: 0.2449 - val_accuracy: 0.9529 - val_loss: 0.2597 - learning_rate: 5.0000e-04
# Epoch 10/20
# 1325/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9565 - loss: 0.2242
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 36s 27ms/step - accuracy: 0.9565 - loss: 0.2242 - val_accuracy: 0.9466 - val_loss: 0.2776 - learning_rate: 5.0000e-04
# Epoch 11/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 36s 27ms/step - accuracy: 0.9660 - loss: 0.1918 - val_accuracy: 0.9558 - val_loss: 0.2442 - learning_rate: 2.5000e-04
# Epoch 12/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9720 - loss: 0.1680 - val_accuracy: 0.9548 - val_loss: 0.2340 - learning_rate: 2.5000e-04
# Epoch 13/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 36s 27ms/step - accuracy: 0.9750 - loss: 0.1564 - val_accuracy: 0.9569 - val_loss: 0.2328 - learning_rate: 2.5000e-04
# Epoch 14/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9789 - loss: 0.1428 - val_accuracy: 0.9552 - val_loss: 0.2374 - learning_rate: 2.5000e-04
# Epoch 15/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 36s 27ms/step - accuracy: 0.9810 - loss: 0.1347 - val_accuracy: 0.9536 - val_loss: 0.2494 - learning_rate: 2.5000e-04
# Epoch 16/20
# 1325/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9808 - loss: 0.1294
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 36s 27ms/step - accuracy: 0.9808 - loss: 0.1294 - val_accuracy: 0.9563 - val_loss: 0.2401 - learning_rate: 2.5000e-04
# Epoch 17/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 36s 27ms/step - accuracy: 0.9873 - loss: 0.1121 - val_accuracy: 0.9561 - val_loss: 0.2457 - learning_rate: 1.2500e-04
# Epoch 18/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 27ms/step - accuracy: 0.9884 - loss: 0.1060 - val_accuracy: 0.9563 - val_loss: 0.2410 - learning_rate: 1.2500e-04
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Metadata for seed 42 saved to /kaggle/working/residual_attention_gan/metadata_residual_attention_gan_seed_42.json
#
# --- Training 'residual_attention_gan' with Seed: 1999 ---
# Epoch 1/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 65s 34ms/step - accuracy: 0.4868 - loss: 1.8516 - val_accuracy: 0.8800 - val_loss: 0.4775 - learning_rate: 0.0010
# Epoch 2/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 36s 27ms/step - accuracy: 0.8469 - loss: 0.5915 - val_accuracy: 0.8899 - val_loss: 0.4818 - learning_rate: 0.0010
# Epoch 3/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 36s 27ms/step - accuracy: 0.8831 - loss: 0.4856 - val_accuracy: 0.8567 - val_loss: 0.6274 - learning_rate: 0.0010
# Epoch 4/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.8994 - loss: 0.4347 - val_accuracy: 0.9043 - val_loss: 0.4175 - learning_rate: 0.0010
# Epoch 5/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9132 - loss: 0.3919 - val_accuracy: 0.9196 - val_loss: 0.3648 - learning_rate: 0.0010
# Epoch 6/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 36s 27ms/step - accuracy: 0.9208 - loss: 0.3647 - val_accuracy: 0.9186 - val_loss: 0.3745 - learning_rate: 0.0010
# Epoch 7/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9270 - loss: 0.3447 - val_accuracy: 0.9487 - val_loss: 0.2764 - learning_rate: 0.0010
# Epoch 8/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9343 - loss: 0.3233 - val_accuracy: 0.9378 - val_loss: 0.3055 - learning_rate: 0.0010
# Epoch 9/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9360 - loss: 0.3114 - val_accuracy: 0.9458 - val_loss: 0.2849 - learning_rate: 0.0010
# Epoch 10/20
# 1324/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9440 - loss: 0.2869
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9440 - loss: 0.2870 - val_accuracy: 0.9467 - val_loss: 0.2877 - learning_rate: 0.0010
# Epoch 11/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 36s 27ms/step - accuracy: 0.9607 - loss: 0.2335 - val_accuracy: 0.9544 - val_loss: 0.2562 - learning_rate: 5.0000e-04
# Epoch 12/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9661 - loss: 0.2030 - val_accuracy: 0.9576 - val_loss: 0.2393 - learning_rate: 5.0000e-04
# Epoch 13/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9688 - loss: 0.1894 - val_accuracy: 0.9502 - val_loss: 0.2662 - learning_rate: 5.0000e-04
# Epoch 14/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9730 - loss: 0.1749 - val_accuracy: 0.9539 - val_loss: 0.2485 - learning_rate: 5.0000e-04
# Epoch 15/20
# 1324/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9728 - loss: 0.1661
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9728 - loss: 0.1661 - val_accuracy: 0.9484 - val_loss: 0.2655 - learning_rate: 5.0000e-04
# Epoch 16/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9821 - loss: 0.1371 - val_accuracy: 0.9553 - val_loss: 0.2512 - learning_rate: 2.5000e-04
# Epoch 17/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9862 - loss: 0.1216 - val_accuracy: 0.9559 - val_loss: 0.2474 - learning_rate: 2.5000e-04
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 12.
# Metadata for seed 1999 saved to /kaggle/working/residual_attention_gan/metadata_residual_attention_gan_seed_1999.json
#
# --- Training 'residual_attention_gan' with Seed: 2025 ---
# Epoch 1/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 64s 34ms/step - accuracy: 0.4796 - loss: 1.8732 - val_accuracy: 0.8850 - val_loss: 0.4606 - learning_rate: 0.0010
# Epoch 2/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 36s 27ms/step - accuracy: 0.8440 - loss: 0.6020 - val_accuracy: 0.9082 - val_loss: 0.3768 - learning_rate: 0.0010
# Epoch 3/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 27ms/step - accuracy: 0.8801 - loss: 0.4939 - val_accuracy: 0.9244 - val_loss: 0.3506 - learning_rate: 0.0010
# Epoch 4/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.8978 - loss: 0.4394 - val_accuracy: 0.9376 - val_loss: 0.3105 - learning_rate: 0.0010
# Epoch 5/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9108 - loss: 0.3966 - val_accuracy: 0.9370 - val_loss: 0.3122 - learning_rate: 0.0010
# Epoch 6/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9185 - loss: 0.3748 - val_accuracy: 0.9396 - val_loss: 0.3099 - learning_rate: 0.0010
# Epoch 7/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9265 - loss: 0.3459 - val_accuracy: 0.9298 - val_loss: 0.3456 - learning_rate: 0.0010
# Epoch 8/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9306 - loss: 0.3303 - val_accuracy: 0.9351 - val_loss: 0.3305 - learning_rate: 0.0010
# Epoch 9/20
# 1324/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9366 - loss: 0.3122
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9366 - loss: 0.3122 - val_accuracy: 0.9330 - val_loss: 0.3272 - learning_rate: 0.0010
# Epoch 10/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9563 - loss: 0.2493 - val_accuracy: 0.9544 - val_loss: 0.2580 - learning_rate: 5.0000e-04
# Epoch 11/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9613 - loss: 0.2184 - val_accuracy: 0.9503 - val_loss: 0.2607 - learning_rate: 5.0000e-04
# Epoch 12/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9619 - loss: 0.2080 - val_accuracy: 0.9468 - val_loss: 0.2751 - learning_rate: 5.0000e-04
# Epoch 13/20
# 1325/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9668 - loss: 0.1895
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9668 - loss: 0.1895 - val_accuracy: 0.9469 - val_loss: 0.2756 - learning_rate: 5.0000e-04
# Epoch 14/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9771 - loss: 0.1578 - val_accuracy: 0.9578 - val_loss: 0.2368 - learning_rate: 2.5000e-04
# Epoch 15/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9807 - loss: 0.1409 - val_accuracy: 0.9549 - val_loss: 0.2383 - learning_rate: 2.5000e-04
# Epoch 16/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 36s 27ms/step - accuracy: 0.9825 - loss: 0.1325 - val_accuracy: 0.9537 - val_loss: 0.2452 - learning_rate: 2.5000e-04
# Epoch 17/20
# 1325/1326 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9844 - loss: 0.1213
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 36s 27ms/step - accuracy: 0.9844 - loss: 0.1213 - val_accuracy: 0.9552 - val_loss: 0.2478 - learning_rate: 2.5000e-04
# Epoch 18/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9894 - loss: 0.1071 - val_accuracy: 0.9563 - val_loss: 0.2479 - learning_rate: 1.2500e-04
# Epoch 19/20
# 1326/1326 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9908 - loss: 0.0991 - val_accuracy: 0.9551 - val_loss: 0.2436 - learning_rate: 1.2500e-04
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Metadata for seed 2025 saved to /kaggle/working/residual_attention_gan/metadata_residual_attention_gan_seed_2025.json

# %%
best_model = load_model(best_seed_checkpoint_path)

best_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 40, 101,   │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 40, 101,   │        320 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 40, 101,   │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 40, 101,   │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 40, 101,   │      9,248 │ re_lu[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 101,   │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 40, 101,   │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 40, 101,   │      9,248 │ re_lu_1[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 101,   │        128 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 40, 101,   │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ re_lu[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 40, 101,   │          0 │ add[0][0]         │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 20, 51,    │     18,496 │ re_lu_2[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 51,    │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 20, 51,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 20, 51,    │     36,928 │ re_lu_3[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 20, 51,    │      2,112 │ re_lu_2[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 51,    │        256 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 51,    │        256 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 20, 51,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 20, 51,    │          0 │ add_1[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 10, 26,    │     73,856 │ re_lu_4[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 26,    │        512 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 10, 26,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 10, 26,    │    147,584 │ re_lu_5[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 10, 26,    │      8,320 │ re_lu_4[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 26,    │        512 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 26,    │        512 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 10, 26,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 10, 26,    │          0 │ add_2[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ re_lu_6[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 128) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1, 1, 16)  │      2,048 │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1, 1, 128) │      2,048 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 10, 26,    │          0 │ re_lu_6[0][0],    │
# │                     │ 128)              │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 5, 13,     │    147,584 │ multiply[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, 5, 13,     │          0 │ conv2d_9[0][0]    │
# │ (LeakyReLU)         │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 5, 13,     │          0 │ leaky_re_lu[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 3, 7, 256) │    295,168 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu_1       │ (None, 3, 7, 256) │          0 │ conv2d_10[0][0]   │
# │ (LeakyReLU)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 3, 7, 256) │          0 │ leaky_re_lu_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ feature_embedding   │ (None, 256)       │          0 │ dropout_1[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 35)        │      8,995 │ feature_embeddin… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,291,243 (8.74 MB)
#  Trainable params: 763,299 (2.91 MB)
#  Non-trainable params: 1,344 (5.25 KB)
#  Optimizer params: 1,526,600 (5.82 MB)

# %%
val_loss, val_acc = best_model.evaluate(val_ds)

test_loss, test_acc = best_model.evaluate(test_ds)

print(f"\nValidation accuracy: {val_acc:.4f}")
print(f"Validation loss: {val_loss:.4f}")

print(f"\nTest accuracy: {test_acc:.4f}")
print(f"Test loss: {test_loss:.4f}")
# Out:
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9629 - loss: 0.2253
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9579 - loss: 0.2219
#
# Validation accuracy: 0.9578
# Validation loss: 0.2368
#
# Test accuracy: 0.9543
# Test loss: 0.2360

# %%
save_and_plot_results(history, best_model, model_name, saving_dir)
# Out:
# --- Saving results for model: residual_attention_gan ---
# Loss plot saved to /kaggle/working/residual_attention_gan/residual_attention_gan_loss.png
# Accuracy plot saved to /kaggle/working/residual_attention_gan/residual_attention_gan_accuracy.png
# Training history saved to /kaggle/working/residual_attention_gan/training_history.pkl
#
# --- Plotting model architecture for: residual_attention_gan ---
# Model architecture plot saved

# %% [markdown]
# # Models Evaluation

# %%
class ModelEvaluator:
    def __init__(self, models_dir, test_data, test_labels, index_to_label, custom_objects=None, output_dir="output"):
        self.models_dir = models_dir
        self.X_test, self.y_test = test_data, test_labels
        self.index_to_label = index_to_label
        self.custom_objects = custom_objects
        self.output_dir = output_dir
        os.makedirs(self.output_dir, exist_ok=True)
        self.results = []
        self.df_results = None

    def _measure_inference_time(self, model, num_runs=10):
        """Evaluate the inference time of a model"""
        dummy_input = self.X_test[:1]
        _ = model.predict(dummy_input, verbose=0)
        
        start_time = time.time()
        for _ in range(num_runs):
            _ = model.predict(self.X_test, verbose=0, batch_size=64)
        end_time = time.time()
        
        avg_time_per_sample_ms = ((end_time - start_time) / num_runs / len(self.X_test)) * 1000
        return avg_time_per_sample_ms

    def _calculate_multiclass_auc(self, y_true, y_pred_proba, all_classes):
        """Computes AUC for the multi-class problem using OvR"""
        y_true_binarized = label_binarize(y_true, classes=all_classes)
        return roc_auc_score(y_true_binarized, y_pred_proba, multi_class='ovr', average='macro')

    def plot_tsne_embeddings(self, model, model_name):
        print(f"\n--- Generating T-SNE plot for {model_name} ---")
        
        try:
            feature_layer = model.get_layer(name="feature_embedding")
        except ValueError:
            print("Warning: 'feature_embedding' layer not found. Falling back to an alternative.")
            if isinstance(model.layers[-2], layers.Dropout):
                feature_layer = model.layers[-3]
            else:
                feature_layer = model.layers[-2]

        feature_extractor = models.Model(
            inputs=model.input,
            outputs=feature_layer.output
        )

        features = feature_extractor.predict(self.X_test, batch_size=64)
        tsne = TSNE(n_components=2, perplexity=30, n_iter=1000, random_state=42)
        tsne_results = tsne.fit_transform(features)
        df_tsne = pd.DataFrame(tsne_results, columns=['tsne1', 'tsne2'])
        df_tsne['label'] = [self.index_to_label[l] for l in self.y_test]
        plt.figure(figsize=(16, 10))
        sns.scatterplot(x="tsne1", y="tsne2", hue="label", palette=sns.color_palette("hsv", len(self.index_to_label)), data=df_tsne, legend="full", alpha=0.8)
        plt.title(f'T-SNE Visualization of Feature Embeddings - {model_name}', fontsize=16)
        plt.xlabel('T-SNE Dimension 1', fontsize=12)
        plt.ylabel('T-SNE Dimension 2', fontsize=12)
        plt.legend(title='Class', loc='best', markerscale=2)
        plt.grid(True)
        save_path = os.path.join(self.output_dir, model_name, f"tsne_visualization_{model_name}.png")
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        plt.savefig(save_path)
        plt.show()
        print(f"T-SNE plot saved to {save_path}")

    def plot_error_analysis(self, model, y_pred, model_name, num_samples=9):
        print(f"\n--- Generating error analysis plots for {model_name} ---")
        misclassified_indices = np.where(y_pred != self.y_test)[0]
        if len(misclassified_indices) == 0:
            print("No misclassified samples found.")
            return
        num_to_plot = min(num_samples, len(misclassified_indices))
        random_indices = np.random.choice(misclassified_indices, size=num_to_plot, replace=False)
        fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 12))
        fig.suptitle(f'Error Analysis: Misclassified Samples - {model_name}', fontsize=20)
        for i, ax in enumerate(axes.flatten()):
            if i >= num_to_plot:
                ax.axis('off')
                continue
            idx = random_indices[i]
            spectrogram = np.squeeze(self.X_test[idx])
            true_label = self.index_to_label[self.y_test[idx]]
            pred_label = self.index_to_label[y_pred[idx]]
            img = librosa.display.specshow(spectrogram, sr=16000, x_axis='time', y_axis='mel', ax=ax)
            ax.set_title(f"True: '{true_label}'\nPredicted: '{pred_label}'")
        plt.tight_layout(rect=[0, 0.03, 1, 0.95])
        save_path = os.path.join(self.output_dir, model_name, f"error_analysis_{model_name}.png")
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        plt.savefig(save_path)
        plt.show()
        print(f"Error analysis plot saved to {save_path}")

    def run_evaluation(self):

        model_runs = {}
        for folder_name in os.listdir(self.models_dir):
            if os.path.isdir(os.path.join(self.models_dir, folder_name)):

                if folder_name in ['.virtual_documents', 'evaluation_output']:
                    continue
                
                model_path = os.path.join(self.models_dir, folder_name)
                for file in os.listdir(model_path):
                    if file.startswith('metadata_') and file.endswith('.json'):
                        model_name_base = file.split('_seed_')[0].replace('metadata_', '')
                        if model_name_base not in model_runs:
                            model_runs[model_name_base] = []
                        
                        seed = file.split('_seed_')[1].split('.json')[0]
                        keras_file = f"{model_name_base}_seed_{seed}_best.keras"
                        
                        if os.path.exists(os.path.join(model_path, keras_file)):
                            model_runs[model_name_base].append({
                                'metadata_path': os.path.join(model_path, file),
                                'model_path': os.path.join(model_path, keras_file)
                            })

        for model_name, runs in model_runs.items():

            print(f"\n--- Evaluating all {len(runs)} seeds for {model_name} ---")
            seed_results_list = []

            for run in runs:
                try:
                    model = load_model(run['model_path'], custom_objects=self.custom_objects)
                    with open(run['metadata_path'], 'r') as f:
                        metadata = json.load(f)
                except Exception as e:
                    print(f"Skipping run due to error: {e}")
                    continue

                y_pred_proba = model.predict(self.X_test, batch_size=64)
                y_pred = np.argmax(y_pred_proba, axis=1)
                report = classification_report(self.y_test, y_pred, target_names=list(self.index_to_label.values()), output_dict=True, zero_division=0)
                inference_time = self._measure_inference_time(model)
                all_classes = list(range(len(self.index_to_label)))
                auc_score = self._calculate_multiclass_auc(self.y_test, y_pred_proba, all_classes)
                model_size_mb = round(os.path.getsize(run['model_path']) / (1024 * 1024), 2)

                seed_results_list.append({
                    "test_accuracy": report['accuracy'], "f1_macro": report['macro avg']['f1-score'],
                    "precision_macro": report['macro avg']['precision'], "recall_macro": report['macro avg']['recall'],
                    "auc_macro_ovr": auc_score, "num_params": metadata.get("num_params"),
                    "model_size_mb": model_size_mb, "inference_time_ms_per_sample": inference_time
                })

            if not seed_results_list: continue
            df_seeds = pd.DataFrame(seed_results_list)
            
            aggregated_results = {"model_name": model_name}
            for col in df_seeds.columns:
                if pd.api.types.is_numeric_dtype(df_seeds[col]) and col not in ["num_params", "model_size_mb"]:
                    aggregated_results[f"{col}_mean"] = df_seeds[col].mean()
                    aggregated_results[f"{col}_std"] = df_seeds[col].std()
                elif col in ["num_params", "model_size_mb"]:
                    aggregated_results[col] = df_seeds[col].iloc[0]
            
            self.results.append(aggregated_results)

        if self.results:
            self.df_results = pd.DataFrame(self.results)
            self.df_results = self.df_results.sort_values(by='f1_macro_mean', ascending=False).reset_index(drop=True)
            self._calculate_final_score()
            self.plot_comparison_scatter()
            self.export_results_csv()

    def _calculate_final_score(self, weights_norm=None, weights_rank=None):
        if self.df_results is None or self.df_results.empty: return
        df = self.df_results.copy()
        
        if weights_norm is None:
            weights_norm = {
                'f1_macro_mean': 0.4, 'test_accuracy_mean': 0.15, 'auc_macro_ovr_mean': 0.1,
                'recall_macro_mean': 0.05, 'precision_macro_mean': 0.05,
                'inference_time_ms_per_sample_mean': -0.1,
                'model_size_mb': -0.05, 'num_params': -0.05,
                'f1_macro_std': -0.05
            }
            
        scaler = MinMaxScaler()
        score_norm = np.zeros(len(df))
        
        for metric, weight in weights_norm.items():
            if metric in df.columns:
                scaled_metric = scaler.fit_transform(df[[metric]])
                if weight < 0:
                    score_norm += (1 - scaled_metric.flatten()) * abs(weight)
                else:
                    score_norm += scaled_metric.flatten() * weight
                    
        df['norm_score'] = score_norm

        if weights_rank is None:
            weights_rank = {'performance': 0.6, 'efficiency': 0.4}
            
        perf_metrics = ['f1_macro_mean', 'test_accuracy_mean', 'auc_macro_ovr_mean']
        
        eff_metrics = ['model_size_mb', 'inference_time_ms_per_sample_mean', 'num_params']
        
        perf_rank_sum = np.zeros(len(df))
        
        for metric in perf_metrics:
            if metric in df.columns: perf_rank_sum += df[metric].rank(ascending=False)
                
        df['performance_score'] = perf_rank_sum / len(perf_metrics)
        eff_rank_sum = np.zeros(len(df))
        
        for metric in eff_metrics:
            if metric in df.columns: eff_rank_sum += df[metric].rank(ascending=True)
                
        df['efficiency_score'] = eff_rank_sum / len(eff_metrics)
        df['final_rank_score'] = (weights_rank['performance'] * df['performance_score'] + weights_rank['efficiency'] * df['efficiency_score'])

        df.columns = [c.replace('_mean', ' (μ)') for c in df.columns]
        df.columns = [c.replace('_std', ' (σ)') for c in df.columns]
        self.df_results = df


    def plot_confusion_matrix(self, y_true, y_pred, model_name):
        cm = confusion_matrix(y_true, y_pred)
        class_names = self.index_to_label.values()
        plt.figure(figsize=(12, 10))
        sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
        plt.title(f"Confusion Matrix - {model_name.replace('_', ' ').title()}", fontsize=16)
        plt.xlabel("Predicted Label", fontsize=12)
        plt.ylabel("True Label", fontsize=12)
        plt.xticks(rotation=45, ha='right')
        plt.yticks(rotation=0)
        plt.tight_layout()
        save_path = os.path.join(self.output_dir, model_name, f"confusion_matrix_{model_name}.png")
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        plt.savefig(save_path)
        plt.show()
        print(f"Confusion matrix saved to {save_path}")

    def plot_comparison_scatter(self):
        if self.df_results is None or self.df_results.empty:
            print("No results to plot.")
            return
    
        df_for_plotting = self.df_results.copy()
        plt.style.use('seaborn-v0_8-whitegrid')
    
        col_map = {
            "f1_macro": "f1_macro (μ)",
            "model_size_mb": "model_size_mb",
            "inference_time_ms_per_sample": "inference_time_ms_per_sample (μ)"
        }
    
        # F1 vs Inference Time
        fig, ax1 = plt.subplots(figsize=(10, 7))
        sns.scatterplot(
            data=df_for_plotting,
            x=col_map["inference_time_ms_per_sample"],
            y=col_map["f1_macro"],
            hue="model_name", s=250, ax=ax1, palette="viridis", style="model_name", markers=True
        )
        ax1.errorbar(
            x=df_for_plotting[col_map["inference_time_ms_per_sample"]],
            y=df_for_plotting[col_map["f1_macro"]],
            xerr=df_for_plotting.get("inference_time_ms_per_sample (σ)"),
            yerr=df_for_plotting.get("f1_macro (σ)"),
            fmt="none", ecolor="gray", capsize=4, alpha=0.6
        )
        ax1.set_title("Performance vs. Inference Time", fontsize=16)
        ax1.set_xlabel("Inference Time per Sample (ms, mean)", fontsize=12)
        ax1.set_ylabel("F1 Score (Macro, mean)", fontsize=12)
        plt.tight_layout()
        plt.savefig(os.path.join(self.output_dir, "f1_vs_inference_time.png"))
        plt.show()

        # F1 vs Model Size
        fig, ax2 = plt.subplots(figsize=(10, 7))
        sns.scatterplot(
            data=df_for_plotting,
            x=col_map["model_size_mb"],
            y=col_map["f1_macro"],
            hue="model_name", s=250, ax=ax2, palette="plasma", style="model_name", markers=True
        )
        ax2.errorbar(
            x=df_for_plotting[col_map["model_size_mb"]],
            y=df_for_plotting[col_map["f1_macro"]],
            yerr=df_for_plotting.get("f1_macro (σ)"),
            fmt="none", ecolor="gray", capsize=4, alpha=0.6
        )
        ax2.set_title("Performance vs. Model Size", fontsize=16)
        ax2.set_xlabel("Model Size (MB)", fontsize=12)
        ax2.set_ylabel("F1 Score (Macro, mean)", fontsize=12)
        plt.tight_layout()
        plt.savefig(os.path.join(self.output_dir, "f1_vs_model_size.png"))
        plt.show()

    def export_results_csv(self):
        if self.df_results is not None:
            output_path = os.path.join(self.output_dir, "evaluation_summary.csv")
            self.df_results.to_csv(output_path, index=False)
            print(f"\nEvaluation summary saved to: {output_path}")

# %%
def evaluate_and_compare_models():
    MODELS_DIR = "/kaggle/working"
    OUTPUT_DIR = "/kaggle/working/evaluation_output"

    test_path = os.path.join(PROCESSED_DATA_DIR, "test")
    _, X_test, y_test = load_dataset(test_path, label_to_index, shuffle=False)

    custom_objects = {
        "Patches": Patches,
        "PatchEncoder": PatchEncoder,
        "PositionalEncoding": PositionalEncoding
    }

    evaluator = ModelEvaluator(
        models_dir=MODELS_DIR,
        test_data=X_test,
        test_labels=y_test,
        index_to_label=index_to_label,
        custom_objects=custom_objects,
        output_dir=OUTPUT_DIR
    )
    evaluator.run_evaluation()
    
    print("\n--- Final Model Ranking ---")
    print(evaluator.df_results)
    
    return evaluator

# %%
def run_final_analysis(evaluator):
    if evaluator.df_results is None or evaluator.df_results.empty:
        print("Evaluation results not found. Please run evaluator.run_evaluation() first.")
        return None, None

    # Look for the best model
    best_model_row = evaluator.df_results.iloc[0]
    best_model_name = best_model_row['model_name']
    print(f"\n\n{'='*50}")
    print(f"STARTING FINAL ANALYSIS FOR BEST MODEL: {best_model_name.upper()}")
    print(f"{'='*50}")

    # Load the best model
    FIXED_SEED = 42
    model_dir = os.path.join(evaluator.models_dir, best_model_name)
    fixed_model_file = f"{best_model_name}_seed_{FIXED_SEED}_best.keras"
    best_model_path = os.path.join(model_dir, fixed_model_file)
    
    if not os.path.exists(best_model_path):
        raise FileNotFoundError(f"Checkpoint con seed {FIXED_SEED} non trovato per {best_model_name}")
    
    try:
        best_model = load_model(best_model_path, custom_objects=evaluator.custom_objects)
        print(f"Successfully loaded best model: {best_model_name} (seed={FIXED_SEED})")
    except Exception as e:
        print(f"Could not load model {best_model_name}. Error: {e}")
        return

    # Predictions
    y_pred_proba = best_model.predict(evaluator.X_test, batch_size=64)
    y_pred = np.argmax(y_pred_proba, axis=1)

    # Confusion MAtrix
    evaluator.plot_confusion_matrix(evaluator.y_test, y_pred, best_model_name)
    
    # T-SNE
    evaluator.plot_tsne_embeddings(best_model, best_model_name)
    
    # Error Analysis 
    evaluator.plot_error_analysis(best_model, y_pred, best_model_name)

    return best_model_path, best_model_name

# %%
evaluator = evaluate_and_compare_models()

best_model_path, best_model_name = run_final_analysis(evaluator)
# Out:
# --- Evaluating all 3 seeds for vision_transformer ---
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
#
# --- Evaluating all 3 seeds for baseline_cnn ---
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
#
# --- Evaluating all 3 seeds for hybrid_cnn_bilstm ---
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
#
# --- Evaluating all 3 seeds for residual_attention_gan ---
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step
#
# --- Evaluating all 3 seeds for hybrid_cnn_transformer ---
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step
#
# --- Evaluating all 3 seeds for residual_cnn ---
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step
# Evaluation summary saved to: /kaggle/working/evaluation_output/evaluation_summary.csv
#
# --- Final Model Ranking ---
#                model_name  test_accuracy (μ)  test_accuracy (σ)  f1_macro (μ)  \
# 0  residual_attention_gan           0.953082           0.002836      0.947478
# 1            residual_cnn           0.950023           0.003318      0.943936
# 2       hybrid_cnn_bilstm           0.945752           0.003816      0.940002
# 3  hybrid_cnn_transformer           0.935635           0.007674      0.927148
# 4      vision_transformer           0.852219           0.013461      0.840842
# 5            baseline_cnn           0.755596           0.016884      0.740486
#
#    f1_macro (σ)  precision_macro (μ)  precision_macro (σ)  recall_macro (μ)  \
# 0      0.003395             0.947800             0.003054          0.947852
# 1      0.003776             0.943042             0.005134          0.945951
# 2      0.004176             0.939124             0.004017          0.941591
# 3      0.008607             0.924068             0.007533          0.932039
# 4      0.014073             0.839726             0.011713          0.849335
# 5      0.016159             0.742600             0.015623          0.753083
#
#    recall_macro (σ)  auc_macro_ovr (μ)  auc_macro_ovr (σ)  num_params  \
# 0          0.003262           0.999504           0.000062      764643
# 1          0.003500           0.999399           0.000052      313315
# 2          0.004089           0.999138           0.000083      148899
# 3          0.008451           0.998940           0.000135      216547
# 4          0.016476           0.995595           0.000925      164643
# 5          0.009655           0.987589           0.000868       32035
#
#    model_size_mb  inference_time_ms_per_sample (μ)  \
# 0           8.92                          0.162826
# 1           3.72                          0.151300
# 2           1.79                          0.137355
# 3           2.65                          0.102213
# 4           2.03                          0.099938
# 5           0.41                          0.104079
#
#    inference_time_ms_per_sample (σ)  norm_score  performance_score  \
# 0                          0.000866    0.800000                1.0
# 1                          0.000280    0.866493                2.0
# 2                          0.001443    0.894551                3.0
# 3                          0.000472    0.883097                4.0
# 4                          0.001319    0.572495                5.0
# 5                          0.001064    0.193415                6.0
#
#    efficiency_score  final_rank_score
# 0          6.000000          3.000000
# 1          5.000000          3.200000
# 2          2.666667          2.866667
# 3          3.333333          3.733333
# 4          2.333333          3.933333
# 5          1.666667          4.266667
#
#
# ==================================================
# STARTING FINAL ANALYSIS FOR BEST MODEL: RESIDUAL_ATTENTION_GAN
# ==================================================
# Successfully loaded best model: residual_attention_gan (seed=42)
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step
# Confusion matrix saved to /kaggle/working/evaluation_output/residual_attention_gan/confusion_matrix_residual_attention_gan.png
#
# --- Generating T-SNE plot for residual_attention_gan ---
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step
# T-SNE plot saved to /kaggle/working/evaluation_output/residual_attention_gan/tsne_visualization_residual_attention_gan.png
#
# --- Generating error analysis plots for residual_attention_gan ---
# Error analysis plot saved to /kaggle/working/evaluation_output/residual_attention_gan/error_analysis_residual_attention_gan.png

# %% [markdown]
# # Model Conversion to TFLite

# %%
print(f"\n--- Converting selected model ({best_model_name}) to TFLite ---")
# Load the Keras model
model = tf.keras.models.load_model(best_model_path)

# Create a TensorFlow Lite converter
converter = tf.lite.TFLiteConverter.from_keras_model(model)

# Default optimizations
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# Convert the model to .tflite
tflite_model = converter.convert()

# Save the .tflite file
with open('model.tflite', 'wb') as f:
  f.write(tflite_model)

print(f"Model '{best_model_name}' converted successfully to model.tflite")
# Out:
# --- Converting selected model (residual_attention_gan) to TFLite ---
# Saved artifact at '/tmp/tmpe4vugvvv'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 40, 101, 1), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 35), dtype=tf.float32, name=None)
# Captures:
#   137768342091536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768342093072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768342093456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768342087888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768342091728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768342092880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768342092304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768342092112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137769579143312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137769579138704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137769579147920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137769579137168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137769579146000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137769579145616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137769388900176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137769388895184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137769388893648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137769579139472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137769388889424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137769377866832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137769377870672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137769377864144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137769377865104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137769377864528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137769377872208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137769377867600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137769377862224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137769377871632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327599824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327597904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137769377871824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327595024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327601552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327599632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327600016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327594064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327598096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327600784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327603664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327604048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327598672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327594256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327602896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327596176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327596944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327594448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327594832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327601360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327600400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327603088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327595984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327599248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327594640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327603856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327604624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327600592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327597136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768327605008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768348466448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768348455504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768348453968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137768348457808: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Model 'residual_attention_gan' converted successfully to model.tflite
# W0000 00:00:1756403230.242598      19 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1756403230.242650      19 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1756403230.284155      19 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled
